# %% [markdown]
# # AUTOENCODER DEMO
# Demo to show how autoencoders can be used to classify patterns in timeseries data
# This demo focusses especially on variational autoencoders
#
# It also is a great platform to play around with different parameters, layers,
# functions and architechtures and see how they affect the models learning

# %% [markdown]
# ## Imports and Setup

# %%
import numpy as np
import holoviews as hv
import panel as pn

hv.extension("bokeh")
hv.renderer("bokeh").theme = "dark_minimal"

# IMPORT ML libs and set random seeds
SEED = 85
import os

os.environ["KERAS_BACKEND"] = "tensorflow"
import keras

keras.utils.set_random_seed(SEED)

import tensorflow as tf

tf.config.experimental.enable_op_determinism()
# Set the global random seed
tf.random.set_seed(SEED)

from keras import backend as K

print(f"Backend: {K.backend()}")

from keras import ops

from numpy.lib.stride_tricks import sliding_window_view

# list avaiable gpus
gpus = tf.config.list_physical_devices("GPU")
for gpu in gpus:
    print("Name:", gpu.name, " Type:", gpu.device_type)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="ef22babe-6957-4f58-a628-e264a84b8782" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"bd08f54f-ac91-4340-9255-901e52e672c1":{"version":"3.4.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"d39ae7e0eac346489600302de06edf8f","client_comm_id":"173016eed73a4187bea815a0afc6b146"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"bd08f54f-ac91-4340-9255-901e52e672c1","roots":{"p1002":"ef22babe-6957-4f58-a628-e264a84b8782"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# 2024-08-04 10:40:53.701569: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-04 10:40:53.725384: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-04 10:40:53.725411: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-04 10:40:53.726665: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-04 10:40:53.730771: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Backend: tensorflow
# Name: /physical_device:GPU:0  Type: GPU

# %%
def limit(x):
    # limits x between 0 and 1
    return (x - x.min()) / (x.max() - x.min())

# %% [markdown]
# ### Signal generator
# Generate random timeseries patterns with specific frequencies in it

# %% [markdown]
# ### Signal Parameters

# %%
# SET PARAMETERS
N_PATTERNS = 30  # number of unique patterns to generate
REPEATS = 10  # how many times the patterns repeat in the total data set
SEQUENCE_LENGTH = 128  # sequence length of each pattern
N_FEATURES = 7  # number of features or input signal channels
NOISE_SIZE = 10000  # number of noise samples that are added
TIME_ENC_L = (1,)  # wavelengths (x * sequence len) in time encoder

# %% [markdown]
# ### Signal Generator Function

# %%
def generate_signal(
    sample_rate=1000,
    duration=1.0,
    num_frequencies=5,
    freq_range=(1, 30),
    frequencies=None,
):
    """
    Generate a signal with given parameters.

    Parameters:
    sample_rate (int): The sample rate in samples per second.
    duration (float): The duration of the signal in seconds.
    num_frequencies (int): The number of unique frequencies in the signal.
    freq_range (tuple): The range of frequencies.

    Returns:
    t (numpy.ndarray): The time values for the samples.
    summed_signal (numpy.ndarray): The generated signal.
    """

    # Generate the time values for the samples
    t = np.arange(int(sample_rate * duration)) / sample_rate

    # Define the frequencies
    # frequencies = np.random.uniform(freq_range[0], freq_range[1], num_frequencies)
    if frequencies is None:
        frequencies = np.random.choice(
            np.linspace(*freq_range, freq_range[1] * 10), num_frequencies, replace=False
        )
    generate_signal.frequencies = frequencies

    # Generate the signal
    signal = np.sin(2 * np.pi * frequencies[:, None] * t)

    # Sum the signal
    summed_signal = np.sum(signal, axis=0)

    return t, summed_signal


# Use the function to generate a signal
t, summed_signal = generate_signal(128, 1)

# Plot the signal
title = (
    "Example signal with: "
    + ", ".join([f"{i:.2f}" for i in sorted(generate_signal.frequencies)])
    + " Hz. signals"
)
pn.Row(
    hv.Curve((t, summed_signal)).opts(
        width=600, title=title, xlabel="time", ylabel="signal"
    )
)
# Out:
# Row
#     [0] HoloViews(Curve, height=300, sizing_mode='fixed', width=600)

# %% [markdown]
# ### Data Generator Function

# %%
def make_dataset(
    seq_len, n_feat, n_patterns, repeats, noise_size, time_encoder_lengths, dtype="f4"
):
    """
    Generates a dataset with specified patterns, noise, and time encoding.

    Parameters:
    seq_len (int): Length of each sequence.
    n_feat (int): Number of features in each sequence.
    n_patterns (int): Number of distinct patterns to generate.
    repeats (int): Number of times each pattern is repeated.
    noise_size (int): Number of noise sequences to add.
    time_encoder_lengths (list): List of lengths for the time encoder.
    dtype: np.dtype of output

    Returns:
    tuple: A tuple containing:
        - X (numpy.ndarray): The generated dataset with shape (total_sequences, seq_len, n_feat + 1).
        - labels (numpy.ndarray): The labels for each sequence with shape (total_sequences,).

    The function performs the following steps:
    1. Generates patterns and repeats them.
    2. Adds noise to the dataset.
    3. Limits the values between 0 and 1.
    4. Creates a time encoder and adds it to the dataset.
    5. Shuffles the dataset and applies a sliding window view.
    6. Creates labels for each pattern and noise.
    7. Adds noise to the dataset and limits the values again.

    Example usage:
    X, labels = make_dataset(100, 10, 5, 3, 50, [1, 2, 3])
    """
    X = np.tile(
        np.concatenate(
            [
                np.stack(
                    [generate_signal(seq_len, 1)[1] for i in range(n_feat)],
                    axis=1,
                )  # 1 pattern
                for ii in range(n_patterns)  # all patterns
            ]
        ),
        (repeats, 1),  # repeats
    )

    # add noise
    X = np.concatenate(
        [
            X,
            np.random.normal(X.mean(), X.std(), size=(noise_size, n_feat)),  # noise
        ],
        axis=0,
    ).astype(dtype)

    # limit  between 0 and 1
    X = limit(X)

    # Create time encoder
    time_enc_data = np.zeros(X.shape[0]).astype(dtype)
    for i in time_encoder_lengths:
        time_enc_data += (
            0.5 * (np.cos(2 * i * np.pi * np.arange(X.shape[0]) / seq_len) + 1)
        ).astype(dtype)

    # add time encoder
    X = np.concatenate((X, time_enc_data[:, np.newaxis]), axis=-1)
    idx = np.arange(X.shape[0])
    np.random.shuffle(idx)

    X = np.transpose(sliding_window_view(X, seq_len, axis=0), (0, 2, 1))

    # create shuffle index
    idx = np.arange(X.shape[0])
    np.random.shuffle(idx)

    from scipy import stats

    # Create labels for each pattern and noise
    labels = np.concatenate(
        [
            np.concatenate(
                [
                    np.concatenate([np.full(seq_len, i) for i in range(n_patterns)])
                    for ii in range(repeats)
                ]
            ),  # labels for patterns
            np.full(noise_size, -1),
        ],  # label for noise
    )

    # make sliding window and select mode for each window
    labels = sliding_window_view(labels.astype("i2"), seq_len)
    labels = stats.mode(labels, axis=1).mode.squeeze().astype("i2")

    # Shuffle labels in the same way as X
    labels = labels[idx]
    X = X[idx]

    # add some noise
    noise_amp = X[:, :, :-1].std() / 4

    if not np.isfinite(noise_amp):
        # with f2 x.std -> np.inf
        noise_amp = 0.025

    X[:, :, :-1] += np.random.normal(
        -noise_amp / 2, noise_amp / 2, size=X[:, :, :-1].shape
    ).astype(dtype)
    X = limit(X)

    return X, labels


X, labels = make_dataset(
    SEQUENCE_LENGTH, N_FEATURES, N_PATTERNS, REPEATS, NOISE_SIZE, TIME_ENC_L
)

split = int(X.shape[0] * 0.8)
X, X_val = X[:split], X[split:]

labels, labels_val = labels[:split], labels[split:]

# %% [markdown]
# ## Build model

# %%
# Sampling layer for VAE
class Sampling(keras.layers.Layer):
    """
    Uses (z_mean, z_log_var) to sample z,
    the vector encoding a digit.
    """

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.seed_generator = keras.random.SeedGenerator(SEED)

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = ops.shape(z_mean)[0]
        dim = ops.shape(z_mean)[1]
        epsilon = keras.random.normal(shape=(batch, dim), seed=self.seed_generator)
        return z_mean + ops.exp(0.5 * z_log_var) * epsilon

# %%
# VAE main model class
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def compute_loss(self, data, training=True):
        if isinstance(data, tuple):
            data = data[0]

        z_mean, z_log_var, z = self.encoder(data)
        reconstruction = self.decoder(z)
        reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum(
                keras.losses.mean_squared_error(data, reconstruction),
            )
        )
        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
        total_loss = reconstruction_loss + kl_loss
        return total_loss, reconstruction_loss, kl_loss

    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        reconstruction = self.decoder(z)
        return reconstruction

    def train_step(self, data):
        with tf.GradientTape() as tape:
            total_loss, reconstruction_loss, kl_loss = self.compute_loss(data)
            grads = tape.gradient(total_loss, self.trainable_weights)
            self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

            self.total_loss_tracker.update_state(total_loss)
            self.reconstruction_loss_tracker.update_state(reconstruction_loss)
            self.kl_loss_tracker.update_state(kl_loss)
            return {
                "loss": self.total_loss_tracker.result(),
                "reconstruction_loss": self.reconstruction_loss_tracker.result(),
                "kl_loss": self.kl_loss_tracker.result(),
            }

    def test_step(self, data):
        total_loss, reconstruction_loss, kl_loss = self.compute_loss(
            data, training=False
        )
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": total_loss,
            "reconstruction_loss": reconstruction_loss,
            "kl_loss": kl_loss,
        }

# %%
def build_model(seq_len, n_feat, conv_filts=32, time_bypass=False):
    latent_dim = 2  # Do not change -> will break cluster plot

    encoder_inputs = keras.Input(shape=(seq_len, n_feat))

    # split time trace from input data if time in encoder is disabled
    if not time_bypass:
        x = encoder_inputs
    else:
        x = encoder_inputs[:, :, :-1]
        time_enc = encoder_inputs[:, :, -1]

    # Convulutional layers to detect patterns
    for n_filt in (int(seq_len / i) for i in (4, 2, 1)):
        x = keras.layers.Conv1D(
            conv_filts,
            kernel_size=3,
            activation="relu",
            padding="same",
            strides=2,
        )(x)
        x = keras.layers.BatchNormalization()(x)

        # feature attention
        attention = keras.layers.MultiHeadAttention(num_heads=4, key_dim=4)(x, x)
        attention = keras.layers.LayerNormalization(epsilon=1e-6)(attention)
        x = attention * x

    #  fully connected layer
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(n_feat, activation="relu")(x)

    # VAE part
    z_mean = keras.layers.Dense(latent_dim, name="z_mean")(x)
    z_log_var = keras.layers.Dense(latent_dim, name="z_log_var")(x)
    z = Sampling(name="bottleneck")([z_mean, z_log_var])

    # pass time encoding to decoder if not encoded in the encoder
    if time_bypass:
        time_enc = time_enc[:, -1:]
        z = keras.layers.Concatenate()([z, time_enc])

    vae_encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
    vae_encoder.summary()

    # DECODER
    latent_inputs = keras.Input(shape=(vae_encoder.output[-1].shape[-1],))

    x = keras.layers.Dense(
        n_feat**2, activation="relu", name=f"decoder_expand", kernel_regularizer="L1L2"
    )(latent_inputs)

    x = keras.layers.Reshape((x.shape[-1] // n_feat, n_feat))(x)

    # # scale up signal to original dimensions
    for i in range(4):
        x = keras.layers.Conv1DTranspose(
            conv_filts, kernel_size=3, strides=2, activation="relu", padding="same"
        )(x)
        x = keras.layers.BatchNormalization()(x)

    # GRU
    x = keras.layers.GRU((n_feat - time_bypass) * 16, return_sequences=True)(x)

    # Output attention:
    attention = keras.layers.MultiHeadAttention(num_heads=4, key_dim=4)(x, x)
    attention = keras.layers.LayerNormalization(epsilon=1e-6)(attention)
    x = x * attention

    # output
    x = keras.layers.Conv1D(
        n_feat - time_bypass, kernel_size=5, activation="relu", padding="same"
    )(x)

    if time_bypass:
        time_enc = latent_inputs[:, latent_dim:]
        time_enc = keras.layers.Dense(seq_len // 8, activation="relu")(time_enc)
        time_enc = keras.layers.Dense(seq_len, activation="relu")(time_enc)
        time_enc = keras.layers.Reshape((seq_len, 1))(time_enc)
        x = keras.layers.Concatenate()([x, time_enc])

    decoder_outputs = x
    decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
    decoder.summary()

    return vae_encoder, decoder


nfeat = N_FEATURES + 1  # N_FEATURES + 1 for time encoding
vae_encoder, decoder = build_model(SEQUENCE_LENGTH, nfeat, nfeat * 4, False)
# Out:
# 2024-08-04 10:40:56.907306: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14196 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 8)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, 128, 7)    │          0 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 64, 32)    │        704 │ get_item[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64, 32)    │        128 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 64, 32)    │      2,128 │ batch_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 64, 32)    │         64 │ multi_head_atten… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 64, 32)    │          0 │ layer_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 32, 32)    │      3,104 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32)    │        128 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 32, 32)    │      2,128 │ batch_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 32, 32)    │         64 │ multi_head_atten… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 32, 32)    │          0 │ layer_normalizat… │
# │ (Multiply)          │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 16, 32)    │      3,104 │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 32)    │        128 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 16, 32)    │      2,128 │ batch_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 16, 32)    │         64 │ multi_head_atten… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 16, 32)    │          0 │ layer_normalizat… │
# │ (Multiply)          │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 512)       │          0 │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 8)         │      4,104 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean (Dense)      │ (None, 2)         │         18 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var (Dense)   │ (None, 2)         │         18 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None, 128)       │          0 │ input_layer[0][0] │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bottleneck          │ (None, 2)         │          0 │ z_mean[0][0],     │
# │ (Sampling)          │                   │            │ z_log_var[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_2          │ (None, 1)         │          0 │ get_item_1[0][0]  │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 3)         │          0 │ bottleneck[0][0], │
# │ (Concatenate)       │                   │            │ get_item_2[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 18,012 (70.36 KB)
#  Trainable params: 17,820 (69.61 KB)
#  Non-trainable params: 192 (768.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 3)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_expand      │ (None, 64)        │        256 │ input_layer_1[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 8, 8)      │          0 │ decoder_expand[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_transpose    │ (None, 16, 32)    │        800 │ reshape[0][0]     │
# │ (Conv1DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 32)    │        128 │ conv1d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_transpose_1  │ (None, 32, 32)    │      3,104 │ batch_normalizat… │
# │ (Conv1DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32)    │        128 │ conv1d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_transpose_2  │ (None, 64, 32)    │      3,104 │ batch_normalizat… │
# │ (Conv1DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 32)    │        128 │ conv1d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_transpose_3  │ (None, 128, 32)   │      3,104 │ batch_normalizat… │
# │ (Conv1DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 32)   │        128 │ conv1d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru (GRU)           │ (None, 128, 112)  │     49,056 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 128, 112)  │      7,328 │ gru[0][0],        │
# │ (MultiHeadAttentio… │                   │            │ gru[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_3          │ (None, 1)         │          0 │ input_layer_1[0]… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 112)  │        224 │ multi_head_atten… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 16)        │         32 │ get_item_3[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 128, 112)  │          0 │ gru[0][0],        │
# │ (Multiply)          │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128)       │      2,176 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 128, 7)    │      3,927 │ multiply_3[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 128, 1)    │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 8)    │          0 │ conv1d_3[0][0],   │
# │ (Concatenate)       │                   │            │ reshape_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 73,623 (287.59 KB)
#  Trainable params: 73,367 (286.59 KB)
#  Non-trainable params: 256 (1.00 KB)

# %%
from keras.utils import plot_model

# plot_model(vae_encoder, rankdir='LR',to_file='encoder.png')
# plot_model(decoder, rankdir='LR',to_file='decoder.png')

# %%
model = VAE(vae_encoder, decoder)
model.compile(optimizer="adamw")

# %%
encoder = keras.Model(vae_encoder.input, vae_encoder.get_layer("z_mean").output)

# %% [markdown]
# ### Callbacks

# %%
callbacks = []

# %%
# learning rate scheduler
def scheduler(epoch, lr):
    if lr < 5e-4:
        return lr

    if epoch > 60:  # Cool-down phase
        return lr * 0.99

    else:  # steady lr
        return lr


lr_cb = keras.callbacks.LearningRateScheduler(scheduler)
callbacks.append(lr_cb)

# %%
colors = [
    "#FFB300",
    "#803E75",
    "#FF6800",
    "#A6BDD7",
    "#C1FF20",
    "#CEA262",
    "#817066",
    "#007D34",
    "#F6768E",
    "#00538A",
    "#FF7A5C",
    "#53377A",
    "#FF8E00",
    "#B32851",
    "#F4C800",
    "#7F180D",
    "#93AA00",
    "#593315",
    "#F13A13",
    "#99FF99",
    "#FF6E76",
    "#1770A4",
    "#23AAFF",
    "#A1CAF1",
    "#C2B280",
    "#967BB6",
    "#CAE0AB",
    "#CE00FF",
    "#F2F3F4",
    "#848482",
    "#008856",
]

# %%
# LIVE PLOTS DEFINED HERE
from holoviews import streams


class EncPlotCallback(keras.callbacks.Callback):
    def __init__(self, encoder, data, labels=None):
        self.data = data
        self.labels = (
            labels if labels is not None else np.ones(data.shape[0], dtype="i4")
        )
        self.encoder = encoder
        self.encode_data()
        self.encoded_stream = streams.Buffer(
            data={"x": self.encoded_data[:, 0], "y": self.encoded_data[:, 1]},
            length=data.shape[0],
        )
        self.plot_enc = hv.DynamicMap(self.encoded_plot, streams=[self.encoded_stream])

    def encode_data(self):
        self.encoded_data = self.encoder.predict(self.data, batch_size=512, verbose=0)

    def on_epoch_end(self, epoch, logs={}):
        self.encode_data()
        self.encoded_stream.send(
            {
                "x": self.encoded_data[:, 0],
                "y": self.encoded_data[:, 1],
            }
        )

    def encoded_plot(self, data):
        xlim = data["x"].min(), data["x"].max()
        ylim = data["y"].min(), data["y"].max()
        mask = self.labels[: data["x"].shape[0]] != -1

        # plot data
        fig = hv.Scatter(
            (
                data["x"][mask],
                data["y"][mask],
                self.labels[: data["x"].shape[0]][mask],
            ),
            vdims=["y", "labels"],
        ).opts(
            size=2,
            color="labels",
            cmap=colors[1:],  # "category20",
            alpha=0.7,
            show_legend=False,
        )

        # plot noise
        fig = fig * hv.Scatter(
            (
                data["x"][~mask],
                data["y"][~mask],
                self.labels[: data["x"].shape[0]][~mask],
            ),
            vdims=["y", "labels"],
            label="noise",
        ).opts(
            size=2,
            color="red",
            alpha=0.7,
            xlim=xlim,
            ylim=ylim,
        )
        return fig.opts(
            width=600,
            height=400,
            title="encoded data",
            shared_axes=False,
        )

    def show_figs(self):
        return self.plot_enc


class LivePlotCallBack(keras.callbacks.Callback):
    def __init__(
        self,
        model,
        x_val,
        y_val=None,
        pars=[],
        plot_opts={},
        batch_size=32,
        loss_par="loss",
        val_loss_par="val_loss",
    ):
        # Define the plot
        self.loss_par = loss_par
        self.val_loss_par = val_loss_par
        self.epoch = -1
        self.pars = pars
        self.mod = model
        self.x_val = x_val
        self.y_val = y_val
        self.y_pred = np.zeros_like(self.y_val)
        self.plot_opts = {
            "width": 300 if self.y_val.shape[1] != 1 else 600,
            "xlabel": "",
            "height": 300,
        }
        self.plot_opts.update(plot_opts)
        self.batch_size = batch_size

        # Define the streams
        self.stream = streams.Buffer(
            data=dict(epoch=np.array([]), loss=np.array([]), val_loss=np.array([])),
            length=10000,
        )

        self.sample_stream = streams.Pipe([])

        # create plots
        self.plot_samp = hv.DynamicMap(self.sample_plot, streams=[self.sample_stream])
        self.plot_loss = hv.DynamicMap(self.loss_plot, streams=[self.stream])

        self.trigger_sample()  # force plot

    # Define the plots
    def sample_plot(self, data):
        epoch = "untrained"
        if self.epoch >= 0:
            epoch = self.epoch

        y = self.y_val  # data.get("y", np.array([]))
        y_pred = self.y_pred  # data.get("y_pred", np.array([]))

        # Create a plot of validation vs prediction
        _figs = []
        if y.shape[1] == 1:
            # make a time trace of all predictions (batchsize is x axis)
            for feature in range(self.y_pred.shape[-1]):
                _figs.append(
                    (
                        hv.Curve(y[:, 0, feature]).relabel("val y")
                        * hv.Curve(y_pred[:, 0, feature]).relabel("pred y")
                    ).opts(
                        title=f"{feature}: {self.pars[feature] if self.pars else 'feature ' + str(feature)}",
                        **self.plot_opts,
                    )
                )
        else:
            # plot over sequence length on x axis
            for sample in range(y.shape[0]):
                for i in range(y.shape[-1]):
                    _figs.append(
                        (
                            hv.Curve(y[sample, :, i]).relabel("val y")
                            * hv.Curve(y_pred[sample, :, i]).relabel("pred y")
                        ).opts(
                            title=f"{sample}: {self.pars[i] if self.pars else 'feature ' + str(i)}",
                            **self.plot_opts,
                        )
                    )

        fig = (
            hv.Layout(_figs)
            .cols(4)
            .opts(title=f"Sample prediction:", shared_axes=False)
        )

        return fig

    def loss_plot(self, data):
        epoch, loss, val_loss = "untrained", "", ""

        if data["epoch"].size > 0:
            epoch = int(data["epoch"][-1]) + 1
            loss = round(data.get("loss", [0])[-1], 4)
            val_loss = round(data.get("val_loss", [0])[-1], 4)

        return hv.Curve(
            (data["epoch"] + 1, data["loss"]), "Epoch", "Loss", label=self.loss_par
        ).opts(
            width=600,
            title=f"Live loss plot (epoch: {epoch}, loss: {loss}, val_loss: {val_loss})",
            color="limegreen",
        ) * hv.Curve(
            (data["epoch"] + 1, data["val_loss"]),
            "Epoch",
            "Loss",
            label=self.val_loss_par,
        ).opts(
            color="red"
        )

    def on_epoch_end(self, epoch, logs={}):
        self.last_logs = logs
        self.epoch = epoch
        self.do_loss(
            epoch, logs.get(self.loss_par, np.nan), logs.get(self.val_loss_par, np.nan)
        )
        self.trigger_sample()

    def do_loss(self, epoch, loss, val_loss):
        self.stream.send(
            {
                "epoch": np.array([epoch]),
                "loss": np.array([loss]),
                "val_loss": np.array([val_loss]),
            }
        )

    def trigger_sample(self):
        if self.epoch >= 0:
            self.y_pred = self.mod.predict(
                self.x_val, verbose=0, batch_size=self.batch_size
            )
        self.sample_stream.send(True)  # send fake data to trigger figure refresh

    def show_figs(
        self,
    ):
        return pn.Column(self.plot_loss, self.plot_samp)

# %%
first_data_idx = (labels >= 0).argmax()  # use argmin to find first non noise point
cb = LivePlotCallBack(
    model,
    X_val[[first_data_idx]],
    X_val[[first_data_idx]],
    batch_size=128,
    loss_par="loss",
    val_loss_par="val_loss",
    pars=[f"Signal {i}" for i in range(N_FEATURES)] + ["time_enc"],
)
enc_cb = EncPlotCallback(encoder, X_val, labels_val)

callbacks.extend([cb, enc_cb])
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722768057.859142  102128 service.cc:145] XLA service 0x7b193c00d330 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1722768057.859180  102128 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 3080 Ti Laptop GPU, Compute Capability 8.6
# 2024-08-04 10:40:57.874593: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-08-04 10:40:57.949082: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# I0000 00:00:1722768058.788579  102128 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %%
def train(batchsize=128, epochs=300):
    model.fit(
        X,
        validation_data=X,
        epochs=epochs,
        callbacks=callbacks,
        batch_size=batchsize,
    )


pn.Column(
    pn.Row(
        cb.plot_loss.opts(height=400),
        enc_cb.show_figs().opts(title="Z_mean Latent Dimension"),
    ),
    cb.plot_samp,
)
# Out:
# Column
#     [0] Row
#         [0] HoloViews(DynamicMap, height=400, sizing_mode='fixed', width=600)
#         [1] HoloViews(DynamicMap, height=400, sizing_mode='fixed', width=600)
#     [1] HoloViews(DynamicMap)

# %%
# The warning raised here is to stop execution of the code until the image is loaded. If you run the next cell immediately the image will not update.
# Please wait until you see the image and then manually run the next cell with the train function

raise UserWarning(
    "Force stop here to give live image time to load, please run next cell manually after image is loaded"
)
# Out:
# ---------------------------------------------------------------------------
# UserWarning                               Traceback (most recent call last)
# Cell In[18], line 4
#       1 # The warning raised here is to stop execution of the code until the image is loaded. If you run the next cell immediately the image will not update.
#       2 # Please wait until you see the image and then manually run the next cell with the train function
# ----> 4 raise UserWarning("Force stop here to give live image time to load, please run next cell manually after image is loaded")
#
# UserWarning: Force stop here to give live image time to load, please run next cell manually after image is loaded

# %%
# %%time
train(batchsize=256, epochs=400)
# Out:
# Epoch 1/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 13s 43ms/step - kl_loss: 1.9157 - loss: 3405.1135 - reconstruction_loss: 3403.1987 - val_kl_loss: 1.0696 - val_loss: 1069.8414 - val_reconstruction_loss: 1068.7719 - learning_rate: 0.0010
# Epoch 2/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - kl_loss: 1.0293 - loss: 1248.0330 - reconstruction_loss: 1247.0035 - val_kl_loss: 0.9590 - val_loss: 1020.8685 - val_reconstruction_loss: 1019.9095 - learning_rate: 0.0010
# Epoch 3/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - kl_loss: 0.7147 - loss: 1169.2278 - reconstruction_loss: 1168.5132 - val_kl_loss: 0.1901 - val_loss: 921.2074 - val_reconstruction_loss: 921.0173 - learning_rate: 0.0010
# Epoch 4/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - kl_loss: 0.1432 - loss: 1066.2831 - reconstruction_loss: 1066.1399 - val_kl_loss: 0.0659 - val_loss: 835.3364 - val_reconstruction_loss: 835.2705 - learning_rate: 0.0010
# Epoch 5/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - kl_loss: 0.0535 - loss: 949.6569 - reconstruction_loss: 949.6033 - val_kl_loss: 0.0384 - val_loss: 747.6019 - val_reconstruction_loss: 747.5635 - learning_rate: 0.0010
# Epoch 6/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - kl_loss: 0.0318 - loss: 868.0011 - reconstruction_loss: 867.9690 - val_kl_loss: 0.0262 - val_loss: 714.2576 - val_reconstruction_loss: 714.2314 - learning_rate: 0.0010
# Epoch 7/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - kl_loss: 0.0245 - loss: 833.8323 - reconstruction_loss: 833.8077 - val_kl_loss: 0.0198 - val_loss: 701.0942 - val_reconstruction_loss: 701.0744 - learning_rate: 0.0010
# Epoch 8/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - kl_loss: 0.0178 - loss: 822.2769 - reconstruction_loss: 822.2593 - val_kl_loss: 0.0125 - val_loss: 700.1226 - val_reconstruction_loss: 700.1100 - learning_rate: 0.0010
# Epoch 9/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - kl_loss: 0.0144 - loss: 821.4810 - reconstruction_loss: 821.4667 - val_kl_loss: 0.0130 - val_loss: 699.9250 - val_reconstruction_loss: 699.9120 - learning_rate: 0.0010
# Epoch 10/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - kl_loss: 0.0122 - loss: 821.3258 - reconstruction_loss: 821.3137 - val_kl_loss: 0.0144 - val_loss: 699.8099 - val_reconstruction_loss: 699.7955 - learning_rate: 0.0010
# Epoch 11/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - kl_loss: 0.0129 - loss: 821.2504 - reconstruction_loss: 821.2377 - val_kl_loss: 0.0126 - val_loss: 699.7895 - val_reconstruction_loss: 699.7769 - learning_rate: 0.0010
# Epoch 12/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - kl_loss: 0.0136 - loss: 821.1952 - reconstruction_loss: 821.1815 - val_kl_loss: 0.0109 - val_loss: 699.6597 - val_reconstruction_loss: 699.6489 - learning_rate: 0.0010
# Epoch 13/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - kl_loss: 0.0128 - loss: 821.0450 - reconstruction_loss: 821.0322 - val_kl_loss: 0.0160 - val_loss: 699.6781 - val_reconstruction_loss: 699.6621 - learning_rate: 0.0010
# Epoch 14/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - kl_loss: 0.0142 - loss: 820.9567 - reconstruction_loss: 820.9422 - val_kl_loss: 0.0142 - val_loss: 699.5640 - val_reconstruction_loss: 699.5498 - learning_rate: 0.0010
# Epoch 15/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - kl_loss: 0.0163 - loss: 820.8422 - reconstruction_loss: 820.8259 - val_kl_loss: 0.0170 - val_loss: 699.4002 - val_reconstruction_loss: 699.3832 - learning_rate: 0.0010
# Epoch 16/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - kl_loss: 0.0177 - loss: 820.7155 - reconstruction_loss: 820.6979 - val_kl_loss: 0.0105 - val_loss: 699.1677 - val_reconstruction_loss: 699.1571 - learning_rate: 0.0010
# Epoch 17/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - kl_loss: 0.0147 - loss: 820.6161 - reconstruction_loss: 820.6012 - val_kl_loss: 0.0191 - val_loss: 699.1823 - val_reconstruction_loss: 699.1632 - learning_rate: 0.0010
# Epoch 18/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 0.0156 - loss: 820.5305 - reconstruction_loss: 820.5148 - val_kl_loss: 0.0103 - val_loss: 699.1288 - val_reconstruction_loss: 699.1185 - learning_rate: 0.0010
# Epoch 19/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0162 - loss: 820.4073 - reconstruction_loss: 820.3910 - val_kl_loss: 0.0214 - val_loss: 699.0347 - val_reconstruction_loss: 699.0133 - learning_rate: 0.0010
# Epoch 20/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - kl_loss: 0.0175 - loss: 820.3610 - reconstruction_loss: 820.3434 - val_kl_loss: 0.0143 - val_loss: 698.9213 - val_reconstruction_loss: 698.9070 - learning_rate: 0.0010
# Epoch 21/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0127 - loss: 820.2331 - reconstruction_loss: 820.2203 - val_kl_loss: 0.0072 - val_loss: 698.8394 - val_reconstruction_loss: 698.8322 - learning_rate: 0.0010
# Epoch 22/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0120 - loss: 820.1548 - reconstruction_loss: 820.1430 - val_kl_loss: 0.0133 - val_loss: 698.7726 - val_reconstruction_loss: 698.7593 - learning_rate: 0.0010
# Epoch 23/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0129 - loss: 820.0317 - reconstruction_loss: 820.0189 - val_kl_loss: 0.0190 - val_loss: 698.8000 - val_reconstruction_loss: 698.7810 - learning_rate: 0.0010
# Epoch 24/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0136 - loss: 819.9807 - reconstruction_loss: 819.9670 - val_kl_loss: 0.0137 - val_loss: 698.5742 - val_reconstruction_loss: 698.5605 - learning_rate: 0.0010
# Epoch 25/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - kl_loss: 0.0126 - loss: 819.8589 - reconstruction_loss: 819.8461 - val_kl_loss: 0.0089 - val_loss: 698.6396 - val_reconstruction_loss: 698.6307 - learning_rate: 0.0010
# Epoch 26/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0130 - loss: 819.7360 - reconstruction_loss: 819.7233 - val_kl_loss: 0.0148 - val_loss: 698.5963 - val_reconstruction_loss: 698.5815 - learning_rate: 0.0010
# Epoch 27/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0126 - loss: 819.6855 - reconstruction_loss: 819.6730 - val_kl_loss: 0.0136 - val_loss: 698.4592 - val_reconstruction_loss: 698.4457 - learning_rate: 0.0010
# Epoch 28/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0147 - loss: 819.4709 - reconstruction_loss: 819.4561 - val_kl_loss: 0.0111 - val_loss: 698.4186 - val_reconstruction_loss: 698.4076 - learning_rate: 0.0010
# Epoch 29/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0112 - loss: 819.3918 - reconstruction_loss: 819.3806 - val_kl_loss: 0.0137 - val_loss: 698.3497 - val_reconstruction_loss: 698.3360 - learning_rate: 0.0010
# Epoch 30/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0118 - loss: 819.2148 - reconstruction_loss: 819.2031 - val_kl_loss: 0.0099 - val_loss: 698.2496 - val_reconstruction_loss: 698.2396 - learning_rate: 0.0010
# Epoch 31/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0117 - loss: 819.1280 - reconstruction_loss: 819.1163 - val_kl_loss: 0.0082 - val_loss: 698.0881 - val_reconstruction_loss: 698.0799 - learning_rate: 0.0010
# Epoch 32/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0103 - loss: 819.0095 - reconstruction_loss: 818.9993 - val_kl_loss: 0.0073 - val_loss: 698.0040 - val_reconstruction_loss: 697.9967 - learning_rate: 0.0010
# Epoch 33/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0090 - loss: 818.8602 - reconstruction_loss: 818.8511 - val_kl_loss: 0.0144 - val_loss: 697.8748 - val_reconstruction_loss: 697.8605 - learning_rate: 0.0010
# Epoch 34/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0102 - loss: 818.7024 - reconstruction_loss: 818.6922 - val_kl_loss: 0.0071 - val_loss: 697.6812 - val_reconstruction_loss: 697.6741 - learning_rate: 0.0010
# Epoch 35/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0098 - loss: 818.5228 - reconstruction_loss: 818.5132 - val_kl_loss: 0.0177 - val_loss: 697.5514 - val_reconstruction_loss: 697.5337 - learning_rate: 0.0010
# Epoch 36/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0112 - loss: 818.2946 - reconstruction_loss: 818.2835 - val_kl_loss: 0.0112 - val_loss: 697.4080 - val_reconstruction_loss: 697.3969 - learning_rate: 0.0010
# Epoch 37/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0114 - loss: 818.0988 - reconstruction_loss: 818.0873 - val_kl_loss: 0.0117 - val_loss: 697.2206 - val_reconstruction_loss: 697.2090 - learning_rate: 0.0010
# Epoch 38/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0109 - loss: 817.8375 - reconstruction_loss: 817.8268 - val_kl_loss: 0.0054 - val_loss: 697.0582 - val_reconstruction_loss: 697.0528 - learning_rate: 0.0010
# Epoch 39/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0085 - loss: 817.6790 - reconstruction_loss: 817.6705 - val_kl_loss: 0.0092 - val_loss: 696.9690 - val_reconstruction_loss: 696.9598 - learning_rate: 0.0010
# Epoch 40/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0070 - loss: 817.3976 - reconstruction_loss: 817.3903 - val_kl_loss: 0.0052 - val_loss: 696.7549 - val_reconstruction_loss: 696.7497 - learning_rate: 0.0010
# Epoch 41/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0059 - loss: 817.2477 - reconstruction_loss: 817.2415 - val_kl_loss: 0.0069 - val_loss: 696.5715 - val_reconstruction_loss: 696.5646 - learning_rate: 0.0010
# Epoch 42/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0051 - loss: 817.0573 - reconstruction_loss: 817.0522 - val_kl_loss: 0.0037 - val_loss: 696.3905 - val_reconstruction_loss: 696.3868 - learning_rate: 0.0010
# Epoch 43/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0041 - loss: 816.8974 - reconstruction_loss: 816.8932 - val_kl_loss: 0.0053 - val_loss: 696.3563 - val_reconstruction_loss: 696.3510 - learning_rate: 0.0010
# Epoch 44/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0042 - loss: 816.7870 - reconstruction_loss: 816.7826 - val_kl_loss: 0.0041 - val_loss: 696.1337 - val_reconstruction_loss: 696.1296 - learning_rate: 0.0010
# Epoch 45/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0035 - loss: 816.6603 - reconstruction_loss: 816.6566 - val_kl_loss: 0.0023 - val_loss: 696.1656 - val_reconstruction_loss: 696.1633 - learning_rate: 0.0010
# Epoch 46/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0026 - loss: 816.5833 - reconstruction_loss: 816.5807 - val_kl_loss: 0.0020 - val_loss: 696.0945 - val_reconstruction_loss: 696.0925 - learning_rate: 0.0010
# Epoch 47/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0028 - loss: 816.5292 - reconstruction_loss: 816.5265 - val_kl_loss: 0.0021 - val_loss: 696.0903 - val_reconstruction_loss: 696.0882 - learning_rate: 0.0010
# Epoch 48/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0027 - loss: 816.4208 - reconstruction_loss: 816.4181 - val_kl_loss: 0.0011 - val_loss: 696.0261 - val_reconstruction_loss: 696.0250 - learning_rate: 0.0010
# Epoch 49/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0017 - loss: 816.3799 - reconstruction_loss: 816.3784 - val_kl_loss: 0.0015 - val_loss: 695.9706 - val_reconstruction_loss: 695.9691 - learning_rate: 0.0010
# Epoch 50/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0020 - loss: 811.7342 - reconstruction_loss: 811.7325 - val_kl_loss: 0.0024 - val_loss: 689.6080 - val_reconstruction_loss: 689.6056 - learning_rate: 0.0010
# Epoch 51/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0019 - loss: 807.8233 - reconstruction_loss: 807.8219 - val_kl_loss: 0.0013 - val_loss: 689.6211 - val_reconstruction_loss: 689.6198 - learning_rate: 0.0010
# Epoch 52/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0016 - loss: 807.7667 - reconstruction_loss: 807.7657 - val_kl_loss: 0.0016 - val_loss: 689.4438 - val_reconstruction_loss: 689.4423 - learning_rate: 0.0010
# Epoch 53/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0016 - loss: 807.7073 - reconstruction_loss: 807.7061 - val_kl_loss: 0.0013 - val_loss: 689.4783 - val_reconstruction_loss: 689.4769 - learning_rate: 0.0010
# Epoch 54/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0018 - loss: 807.6541 - reconstruction_loss: 807.6527 - val_kl_loss: 0.0013 - val_loss: 689.4243 - val_reconstruction_loss: 689.4230 - learning_rate: 0.0010
# Epoch 55/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0017 - loss: 807.6038 - reconstruction_loss: 807.6025 - val_kl_loss: 0.0016 - val_loss: 689.3688 - val_reconstruction_loss: 689.3672 - learning_rate: 0.0010
# Epoch 56/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0017 - loss: 807.5371 - reconstruction_loss: 807.5356 - val_kl_loss: 0.0013 - val_loss: 689.4041 - val_reconstruction_loss: 689.4027 - learning_rate: 0.0010
# Epoch 57/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0018 - loss: 807.5052 - reconstruction_loss: 807.5035 - val_kl_loss: 0.0018 - val_loss: 689.4099 - val_reconstruction_loss: 689.4081 - learning_rate: 0.0010
# Epoch 58/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0018 - loss: 807.4570 - reconstruction_loss: 807.4554 - val_kl_loss: 0.0016 - val_loss: 689.2469 - val_reconstruction_loss: 689.2452 - learning_rate: 0.0010
# Epoch 59/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0017 - loss: 807.4069 - reconstruction_loss: 807.4058 - val_kl_loss: 0.0021 - val_loss: 689.2889 - val_reconstruction_loss: 689.2868 - learning_rate: 0.0010
# Epoch 60/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0024 - loss: 807.4006 - reconstruction_loss: 807.3986 - val_kl_loss: 0.0011 - val_loss: 689.1528 - val_reconstruction_loss: 689.1517 - learning_rate: 0.0010
# Epoch 61/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0029 - loss: 807.3397 - reconstruction_loss: 807.3368 - val_kl_loss: 0.0035 - val_loss: 689.0589 - val_reconstruction_loss: 689.0554 - learning_rate: 0.0010
# Epoch 62/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.0049 - loss: 807.2858 - reconstruction_loss: 807.2809 - val_kl_loss: 0.0087 - val_loss: 688.9169 - val_reconstruction_loss: 688.9081 - learning_rate: 9.9000e-04
# Epoch 63/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - kl_loss: 0.0195 - loss: 807.1741 - reconstruction_loss: 807.1547 - val_kl_loss: 0.0537 - val_loss: 688.8826 - val_reconstruction_loss: 688.8289 - learning_rate: 9.8010e-04
# Epoch 64/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 0.1219 - loss: 807.0398 - reconstruction_loss: 806.9178 - val_kl_loss: 0.3936 - val_loss: 688.5811 - val_reconstruction_loss: 688.1875 - learning_rate: 9.7030e-04
# Epoch 65/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 0.5301 - loss: 806.2909 - reconstruction_loss: 805.7609 - val_kl_loss: 1.0728 - val_loss: 686.1195 - val_reconstruction_loss: 685.0467 - learning_rate: 9.6060e-04
# Epoch 66/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.3277 - loss: 802.6472 - reconstruction_loss: 801.3195 - val_kl_loss: 1.4910 - val_loss: 683.7221 - val_reconstruction_loss: 682.2311 - learning_rate: 9.5099e-04
# Epoch 67/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.5882 - loss: 800.3831 - reconstruction_loss: 798.7948 - val_kl_loss: 1.5682 - val_loss: 682.9584 - val_reconstruction_loss: 681.3903 - learning_rate: 9.4148e-04
# Epoch 68/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6634 - loss: 799.3447 - reconstruction_loss: 797.6813 - val_kl_loss: 1.5386 - val_loss: 682.1906 - val_reconstruction_loss: 680.6520 - learning_rate: 9.3207e-04
# Epoch 69/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6884 - loss: 798.4767 - reconstruction_loss: 796.7884 - val_kl_loss: 1.6843 - val_loss: 681.5014 - val_reconstruction_loss: 679.8171 - learning_rate: 9.2274e-04
# Epoch 70/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.7167 - loss: 797.6891 - reconstruction_loss: 795.9724 - val_kl_loss: 1.7591 - val_loss: 680.8181 - val_reconstruction_loss: 679.0590 - learning_rate: 9.1352e-04
# Epoch 71/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.7145 - loss: 797.2465 - reconstruction_loss: 795.5319 - val_kl_loss: 1.7173 - val_loss: 680.5929 - val_reconstruction_loss: 678.8755 - learning_rate: 9.0438e-04
# Epoch 72/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.7092 - loss: 796.8916 - reconstruction_loss: 795.1824 - val_kl_loss: 1.6621 - val_loss: 680.3806 - val_reconstruction_loss: 678.7185 - learning_rate: 8.9534e-04
# Epoch 73/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.7037 - loss: 796.4609 - reconstruction_loss: 794.7573 - val_kl_loss: 1.6642 - val_loss: 680.1489 - val_reconstruction_loss: 678.4847 - learning_rate: 8.8638e-04
# Epoch 74/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6855 - loss: 796.1772 - reconstruction_loss: 794.4918 - val_kl_loss: 1.6530 - val_loss: 680.0085 - val_reconstruction_loss: 678.3556 - learning_rate: 8.7752e-04
# Epoch 75/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6970 - loss: 796.1326 - reconstruction_loss: 794.4356 - val_kl_loss: 1.6753 - val_loss: 680.2039 - val_reconstruction_loss: 678.5286 - learning_rate: 8.6875e-04
# Epoch 76/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6898 - loss: 795.7767 - reconstruction_loss: 794.0869 - val_kl_loss: 1.6522 - val_loss: 679.7740 - val_reconstruction_loss: 678.1218 - learning_rate: 8.6006e-04
# Epoch 77/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6927 - loss: 795.8642 - reconstruction_loss: 794.1716 - val_kl_loss: 1.6721 - val_loss: 679.3492 - val_reconstruction_loss: 677.6771 - learning_rate: 8.5146e-04
# Epoch 78/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6991 - loss: 795.3987 - reconstruction_loss: 793.6995 - val_kl_loss: 1.6860 - val_loss: 678.9324 - val_reconstruction_loss: 677.2464 - learning_rate: 8.4294e-04
# Epoch 79/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6863 - loss: 795.1264 - reconstruction_loss: 793.4400 - val_kl_loss: 1.7008 - val_loss: 679.2106 - val_reconstruction_loss: 677.5098 - learning_rate: 8.3451e-04
# Epoch 80/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6861 - loss: 795.1381 - reconstruction_loss: 793.4520 - val_kl_loss: 1.6684 - val_loss: 679.2182 - val_reconstruction_loss: 677.5498 - learning_rate: 8.2617e-04
# Epoch 81/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6790 - loss: 794.9305 - reconstruction_loss: 793.2515 - val_kl_loss: 1.6445 - val_loss: 678.7925 - val_reconstruction_loss: 677.1480 - learning_rate: 8.1791e-04
# Epoch 82/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6749 - loss: 794.6574 - reconstruction_loss: 792.9825 - val_kl_loss: 1.6436 - val_loss: 678.5825 - val_reconstruction_loss: 676.9388 - learning_rate: 8.0973e-04
# Epoch 83/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6799 - loss: 794.6383 - reconstruction_loss: 792.9586 - val_kl_loss: 1.6582 - val_loss: 678.7571 - val_reconstruction_loss: 677.0990 - learning_rate: 8.0163e-04
# Epoch 84/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6779 - loss: 794.3470 - reconstruction_loss: 792.6692 - val_kl_loss: 1.6150 - val_loss: 678.8473 - val_reconstruction_loss: 677.2323 - learning_rate: 7.9361e-04
# Epoch 85/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.7166 - loss: 794.4078 - reconstruction_loss: 792.6912 - val_kl_loss: 1.6848 - val_loss: 678.3038 - val_reconstruction_loss: 676.6190 - learning_rate: 7.8568e-04
# Epoch 86/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6858 - loss: 794.0179 - reconstruction_loss: 792.3320 - val_kl_loss: 1.7308 - val_loss: 678.0220 - val_reconstruction_loss: 676.2913 - learning_rate: 7.7782e-04
# Epoch 87/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6958 - loss: 794.0876 - reconstruction_loss: 792.3919 - val_kl_loss: 1.7620 - val_loss: 678.4977 - val_reconstruction_loss: 676.7357 - learning_rate: 7.7004e-04
# Epoch 88/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.7034 - loss: 793.8449 - reconstruction_loss: 792.1415 - val_kl_loss: 1.7341 - val_loss: 677.9551 - val_reconstruction_loss: 676.2210 - learning_rate: 7.6234e-04
# Epoch 89/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6904 - loss: 793.6367 - reconstruction_loss: 791.9464 - val_kl_loss: 1.6513 - val_loss: 677.6534 - val_reconstruction_loss: 676.0021 - learning_rate: 7.5472e-04
# Epoch 90/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6792 - loss: 793.5679 - reconstruction_loss: 791.8887 - val_kl_loss: 1.7062 - val_loss: 677.7830 - val_reconstruction_loss: 676.0767 - learning_rate: 7.4717e-04
# Epoch 91/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.7018 - loss: 793.3449 - reconstruction_loss: 791.6432 - val_kl_loss: 1.7379 - val_loss: 677.6522 - val_reconstruction_loss: 675.9143 - learning_rate: 7.3970e-04
# Epoch 92/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6686 - loss: 793.4653 - reconstruction_loss: 791.7966 - val_kl_loss: 1.6357 - val_loss: 679.2921 - val_reconstruction_loss: 677.6564 - learning_rate: 7.3230e-04
# Epoch 93/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6885 - loss: 795.0064 - reconstruction_loss: 793.3179 - val_kl_loss: 1.6714 - val_loss: 677.4241 - val_reconstruction_loss: 675.7527 - learning_rate: 7.2498e-04
# Epoch 94/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6592 - loss: 793.0165 - reconstruction_loss: 791.3574 - val_kl_loss: 1.6734 - val_loss: 677.9305 - val_reconstruction_loss: 676.2572 - learning_rate: 7.1773e-04
# Epoch 95/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6748 - loss: 793.1215 - reconstruction_loss: 791.4467 - val_kl_loss: 1.6751 - val_loss: 677.3333 - val_reconstruction_loss: 675.6582 - learning_rate: 7.1055e-04
# Epoch 96/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6534 - loss: 792.9396 - reconstruction_loss: 791.2862 - val_kl_loss: 1.6126 - val_loss: 677.8479 - val_reconstruction_loss: 676.2353 - learning_rate: 7.0345e-04
# Epoch 97/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6644 - loss: 793.1777 - reconstruction_loss: 791.5134 - val_kl_loss: 1.6508 - val_loss: 677.1522 - val_reconstruction_loss: 675.5015 - learning_rate: 6.9641e-04
# Epoch 98/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6651 - loss: 792.9407 - reconstruction_loss: 791.2756 - val_kl_loss: 1.7413 - val_loss: 677.3724 - val_reconstruction_loss: 675.6312 - learning_rate: 6.8945e-04
# Epoch 99/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6850 - loss: 792.7949 - reconstruction_loss: 791.1099 - val_kl_loss: 1.6365 - val_loss: 677.5869 - val_reconstruction_loss: 675.9504 - learning_rate: 6.8255e-04
# Epoch 100/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6616 - loss: 792.7739 - reconstruction_loss: 791.1122 - val_kl_loss: 1.6936 - val_loss: 677.2308 - val_reconstruction_loss: 675.5372 - learning_rate: 6.7573e-04
# Epoch 101/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6661 - loss: 792.6971 - reconstruction_loss: 791.0310 - val_kl_loss: 1.5571 - val_loss: 677.1628 - val_reconstruction_loss: 675.6057 - learning_rate: 6.6897e-04
# Epoch 102/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6619 - loss: 792.6597 - reconstruction_loss: 790.9977 - val_kl_loss: 1.6592 - val_loss: 676.9391 - val_reconstruction_loss: 675.2799 - learning_rate: 6.6228e-04
# Epoch 103/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6527 - loss: 792.3570 - reconstruction_loss: 790.7042 - val_kl_loss: 1.7073 - val_loss: 677.1812 - val_reconstruction_loss: 675.4739 - learning_rate: 6.5566e-04
# Epoch 104/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6662 - loss: 792.3620 - reconstruction_loss: 790.6959 - val_kl_loss: 1.6456 - val_loss: 676.9286 - val_reconstruction_loss: 675.2831 - learning_rate: 6.4910e-04
# Epoch 105/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6682 - loss: 792.2672 - reconstruction_loss: 790.5989 - val_kl_loss: 1.6494 - val_loss: 676.9155 - val_reconstruction_loss: 675.2661 - learning_rate: 6.4261e-04
# Epoch 106/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6535 - loss: 792.1978 - reconstruction_loss: 790.5443 - val_kl_loss: 1.5910 - val_loss: 676.9736 - val_reconstruction_loss: 675.3826 - learning_rate: 6.3619e-04
# Epoch 107/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6492 - loss: 792.3099 - reconstruction_loss: 790.6608 - val_kl_loss: 1.6662 - val_loss: 677.0720 - val_reconstruction_loss: 675.4058 - learning_rate: 6.2982e-04
# Epoch 108/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6483 - loss: 792.3356 - reconstruction_loss: 790.6873 - val_kl_loss: 1.6864 - val_loss: 676.8603 - val_reconstruction_loss: 675.1738 - learning_rate: 6.2353e-04
# Epoch 109/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - kl_loss: 1.6639 - loss: 792.3176 - reconstruction_loss: 790.6538 - val_kl_loss: 1.6367 - val_loss: 676.5647 - val_reconstruction_loss: 674.9280 - learning_rate: 6.1729e-04
# Epoch 110/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6489 - loss: 791.9632 - reconstruction_loss: 790.3142 - val_kl_loss: 1.6664 - val_loss: 677.5551 - val_reconstruction_loss: 675.8887 - learning_rate: 6.1112e-04
# Epoch 111/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6780 - loss: 792.1998 - reconstruction_loss: 790.5218 - val_kl_loss: 1.6409 - val_loss: 676.4487 - val_reconstruction_loss: 674.8079 - learning_rate: 6.0501e-04
# Epoch 112/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6402 - loss: 791.8636 - reconstruction_loss: 790.2234 - val_kl_loss: 1.6541 - val_loss: 676.5990 - val_reconstruction_loss: 674.9449 - learning_rate: 5.9896e-04
# Epoch 113/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6354 - loss: 791.9044 - reconstruction_loss: 790.2690 - val_kl_loss: 1.5768 - val_loss: 676.5535 - val_reconstruction_loss: 674.9767 - learning_rate: 5.9297e-04
# Epoch 114/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6286 - loss: 791.8680 - reconstruction_loss: 790.2395 - val_kl_loss: 1.6344 - val_loss: 677.3778 - val_reconstruction_loss: 675.7434 - learning_rate: 5.8704e-04
# Epoch 115/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6607 - loss: 792.3139 - reconstruction_loss: 790.6531 - val_kl_loss: 1.6228 - val_loss: 677.0420 - val_reconstruction_loss: 675.4192 - learning_rate: 5.8117e-04
# Epoch 116/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6430 - loss: 791.8867 - reconstruction_loss: 790.2438 - val_kl_loss: 1.8175 - val_loss: 676.6714 - val_reconstruction_loss: 674.8538 - learning_rate: 5.7535e-04
# Epoch 117/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6738 - loss: 791.7050 - reconstruction_loss: 790.0312 - val_kl_loss: 1.6172 - val_loss: 676.4786 - val_reconstruction_loss: 674.8613 - learning_rate: 5.6960e-04
# Epoch 118/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6570 - loss: 791.7264 - reconstruction_loss: 790.0695 - val_kl_loss: 1.6547 - val_loss: 676.5018 - val_reconstruction_loss: 674.8470 - learning_rate: 5.6391e-04
# Epoch 119/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6691 - loss: 791.8069 - reconstruction_loss: 790.1379 - val_kl_loss: 1.6609 - val_loss: 676.7416 - val_reconstruction_loss: 675.0806 - learning_rate: 5.5827e-04
# Epoch 120/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6594 - loss: 791.8009 - reconstruction_loss: 790.1414 - val_kl_loss: 1.5961 - val_loss: 676.9990 - val_reconstruction_loss: 675.4030 - learning_rate: 5.5268e-04
# Epoch 121/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6518 - loss: 791.9595 - reconstruction_loss: 790.3077 - val_kl_loss: 1.6585 - val_loss: 676.4682 - val_reconstruction_loss: 674.8097 - learning_rate: 5.4716e-04
# Epoch 122/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6695 - loss: 791.6965 - reconstruction_loss: 790.0269 - val_kl_loss: 1.6756 - val_loss: 677.1518 - val_reconstruction_loss: 675.4762 - learning_rate: 5.4169e-04
# Epoch 123/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6448 - loss: 791.7754 - reconstruction_loss: 790.1307 - val_kl_loss: 1.6840 - val_loss: 676.9858 - val_reconstruction_loss: 675.3018 - learning_rate: 5.3627e-04
# Epoch 124/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6644 - loss: 791.8345 - reconstruction_loss: 790.1699 - val_kl_loss: 1.6581 - val_loss: 676.4097 - val_reconstruction_loss: 674.7516 - learning_rate: 5.3091e-04
# Epoch 125/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6710 - loss: 791.5285 - reconstruction_loss: 789.8575 - val_kl_loss: 1.6817 - val_loss: 676.3651 - val_reconstruction_loss: 674.6833 - learning_rate: 5.2560e-04
# Epoch 126/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6404 - loss: 791.5428 - reconstruction_loss: 789.9023 - val_kl_loss: 1.5998 - val_loss: 676.4934 - val_reconstruction_loss: 674.8936 - learning_rate: 5.2034e-04
# Epoch 127/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6566 - loss: 791.9336 - reconstruction_loss: 790.2770 - val_kl_loss: 1.7072 - val_loss: 676.4961 - val_reconstruction_loss: 674.7889 - learning_rate: 5.1514e-04
# Epoch 128/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6620 - loss: 791.5718 - reconstruction_loss: 789.9097 - val_kl_loss: 1.6161 - val_loss: 676.3917 - val_reconstruction_loss: 674.7756 - learning_rate: 5.0999e-04
# Epoch 129/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6537 - loss: 791.5203 - reconstruction_loss: 789.8665 - val_kl_loss: 1.7326 - val_loss: 676.9265 - val_reconstruction_loss: 675.1939 - learning_rate: 5.0489e-04
# Epoch 130/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6738 - loss: 791.6465 - reconstruction_loss: 789.9729 - val_kl_loss: 1.6607 - val_loss: 676.8597 - val_reconstruction_loss: 675.1990 - learning_rate: 4.9984e-04
# Epoch 131/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6759 - loss: 791.8773 - reconstruction_loss: 790.2014 - val_kl_loss: 1.7143 - val_loss: 676.5410 - val_reconstruction_loss: 674.8267 - learning_rate: 4.9984e-04
# Epoch 132/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6591 - loss: 791.5665 - reconstruction_loss: 789.9072 - val_kl_loss: 1.5725 - val_loss: 677.0138 - val_reconstruction_loss: 675.4413 - learning_rate: 4.9984e-04
# Epoch 133/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6526 - loss: 791.5779 - reconstruction_loss: 789.9254 - val_kl_loss: 1.6849 - val_loss: 676.3755 - val_reconstruction_loss: 674.6906 - learning_rate: 4.9984e-04
# Epoch 134/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6575 - loss: 791.4729 - reconstruction_loss: 789.8155 - val_kl_loss: 1.6728 - val_loss: 676.5750 - val_reconstruction_loss: 674.9022 - learning_rate: 4.9984e-04
# Epoch 135/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6708 - loss: 791.4594 - reconstruction_loss: 789.7886 - val_kl_loss: 1.7079 - val_loss: 676.2552 - val_reconstruction_loss: 674.5474 - learning_rate: 4.9984e-04
# Epoch 136/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6607 - loss: 791.5883 - reconstruction_loss: 789.9276 - val_kl_loss: 1.7020 - val_loss: 676.9145 - val_reconstruction_loss: 675.2125 - learning_rate: 4.9984e-04
# Epoch 137/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6528 - loss: 791.4858 - reconstruction_loss: 789.8329 - val_kl_loss: 1.6755 - val_loss: 677.6623 - val_reconstruction_loss: 675.9868 - learning_rate: 4.9984e-04
# Epoch 138/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6376 - loss: 791.7224 - reconstruction_loss: 790.0848 - val_kl_loss: 1.6696 - val_loss: 676.1774 - val_reconstruction_loss: 674.5078 - learning_rate: 4.9984e-04
# Epoch 139/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6485 - loss: 791.3100 - reconstruction_loss: 789.6614 - val_kl_loss: 1.7098 - val_loss: 676.1494 - val_reconstruction_loss: 674.4396 - learning_rate: 4.9984e-04
# Epoch 140/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6631 - loss: 791.6814 - reconstruction_loss: 790.0183 - val_kl_loss: 1.6537 - val_loss: 676.3948 - val_reconstruction_loss: 674.7410 - learning_rate: 4.9984e-04
# Epoch 141/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6740 - loss: 791.3935 - reconstruction_loss: 789.7195 - val_kl_loss: 1.7167 - val_loss: 676.1313 - val_reconstruction_loss: 674.4147 - learning_rate: 4.9984e-04
# Epoch 142/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 1.6739 - loss: 791.3344 - reconstruction_loss: 789.6604 - val_kl_loss: 1.6934 - val_loss: 676.6825 - val_reconstruction_loss: 674.9891 - learning_rate: 4.9984e-04
# Epoch 143/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6807 - loss: 791.5728 - reconstruction_loss: 789.8920 - val_kl_loss: 1.6932 - val_loss: 676.3367 - val_reconstruction_loss: 674.6436 - learning_rate: 4.9984e-04
# Epoch 144/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.6927 - loss: 791.4873 - reconstruction_loss: 789.7947 - val_kl_loss: 1.7471 - val_loss: 676.2366 - val_reconstruction_loss: 674.4895 - learning_rate: 4.9984e-04
# Epoch 145/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.7299 - loss: 791.4189 - reconstruction_loss: 789.6890 - val_kl_loss: 1.7361 - val_loss: 677.1621 - val_reconstruction_loss: 675.4260 - learning_rate: 4.9984e-04
# Epoch 146/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.7153 - loss: 791.9258 - reconstruction_loss: 790.2107 - val_kl_loss: 1.7992 - val_loss: 676.3412 - val_reconstruction_loss: 674.5419 - learning_rate: 4.9984e-04
# Epoch 147/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.7347 - loss: 791.2260 - reconstruction_loss: 789.4913 - val_kl_loss: 1.7698 - val_loss: 676.4774 - val_reconstruction_loss: 674.7075 - learning_rate: 4.9984e-04
# Epoch 148/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.8211 - loss: 791.3783 - reconstruction_loss: 789.5571 - val_kl_loss: 1.9040 - val_loss: 676.0187 - val_reconstruction_loss: 674.1147 - learning_rate: 4.9984e-04
# Epoch 149/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.9836 - loss: 791.1780 - reconstruction_loss: 789.1943 - val_kl_loss: 2.0752 - val_loss: 675.7867 - val_reconstruction_loss: 673.7115 - learning_rate: 4.9984e-04
# Epoch 150/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 2.1283 - loss: 790.9300 - reconstruction_loss: 788.8018 - val_kl_loss: 2.2558 - val_loss: 675.1154 - val_reconstruction_loss: 672.8596 - learning_rate: 4.9984e-04
# Epoch 151/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 2.2558 - loss: 790.0333 - reconstruction_loss: 787.7776 - val_kl_loss: 2.3229 - val_loss: 674.9404 - val_reconstruction_loss: 672.6174 - learning_rate: 4.9984e-04
# Epoch 152/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 2.3318 - loss: 789.4756 - reconstruction_loss: 787.1439 - val_kl_loss: 2.4639 - val_loss: 674.1586 - val_reconstruction_loss: 671.6946 - learning_rate: 4.9984e-04
# Epoch 153/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 2.4626 - loss: 788.6377 - reconstruction_loss: 786.1752 - val_kl_loss: 2.5653 - val_loss: 673.1862 - val_reconstruction_loss: 670.6210 - learning_rate: 4.9984e-04
# Epoch 154/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - kl_loss: 2.5414 - loss: 787.8691 - reconstruction_loss: 785.3276 - val_kl_loss: 2.5552 - val_loss: 674.2208 - val_reconstruction_loss: 671.6656 - learning_rate: 4.9984e-04
# Epoch 155/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 2.6112 - loss: 787.5542 - reconstruction_loss: 784.9429 - val_kl_loss: 2.5710 - val_loss: 672.4832 - val_reconstruction_loss: 669.9122 - learning_rate: 4.9984e-04
# Epoch 156/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - kl_loss: 2.6580 - loss: 786.4717 - reconstruction_loss: 783.8137 - val_kl_loss: 2.6601 - val_loss: 672.1272 - val_reconstruction_loss: 669.4670 - learning_rate: 4.9984e-04
# Epoch 157/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 2.7402 - loss: 785.7527 - reconstruction_loss: 783.0125 - val_kl_loss: 2.7307 - val_loss: 672.3098 - val_reconstruction_loss: 669.5791 - learning_rate: 4.9984e-04
# Epoch 158/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 2.7991 - loss: 785.7755 - reconstruction_loss: 782.9763 - val_kl_loss: 2.9528 - val_loss: 671.1076 - val_reconstruction_loss: 668.1548 - learning_rate: 4.9984e-04
# Epoch 159/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 2.9118 - loss: 784.9571 - reconstruction_loss: 782.0454 - val_kl_loss: 2.9880 - val_loss: 671.2830 - val_reconstruction_loss: 668.2950 - learning_rate: 4.9984e-04
# Epoch 160/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 2.9472 - loss: 784.3791 - reconstruction_loss: 781.4319 - val_kl_loss: 3.0614 - val_loss: 669.6141 - val_reconstruction_loss: 666.5527 - learning_rate: 4.9984e-04
# Epoch 161/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.0575 - loss: 783.6719 - reconstruction_loss: 780.6144 - val_kl_loss: 3.0047 - val_loss: 669.3286 - val_reconstruction_loss: 666.3239 - learning_rate: 4.9984e-04
# Epoch 162/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.0446 - loss: 783.1116 - reconstruction_loss: 780.0670 - val_kl_loss: 3.1405 - val_loss: 669.8096 - val_reconstruction_loss: 666.6691 - learning_rate: 4.9984e-04
# Epoch 163/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.1149 - loss: 783.0978 - reconstruction_loss: 779.9830 - val_kl_loss: 3.1129 - val_loss: 668.4506 - val_reconstruction_loss: 665.3376 - learning_rate: 4.9984e-04
# Epoch 164/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.1170 - loss: 781.8380 - reconstruction_loss: 778.7211 - val_kl_loss: 3.1417 - val_loss: 667.8035 - val_reconstruction_loss: 664.6617 - learning_rate: 4.9984e-04
# Epoch 165/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.1744 - loss: 781.2983 - reconstruction_loss: 778.1241 - val_kl_loss: 3.2182 - val_loss: 667.3355 - val_reconstruction_loss: 664.1173 - learning_rate: 4.9984e-04
# Epoch 166/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.2343 - loss: 780.8879 - reconstruction_loss: 777.6536 - val_kl_loss: 3.2319 - val_loss: 668.8781 - val_reconstruction_loss: 665.6461 - learning_rate: 4.9984e-04
# Epoch 167/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.2448 - loss: 781.6057 - reconstruction_loss: 778.3608 - val_kl_loss: 3.2390 - val_loss: 667.2198 - val_reconstruction_loss: 663.9808 - learning_rate: 4.9984e-04
# Epoch 168/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.2737 - loss: 779.6782 - reconstruction_loss: 776.4046 - val_kl_loss: 3.2598 - val_loss: 666.9501 - val_reconstruction_loss: 663.6903 - learning_rate: 4.9984e-04
# Epoch 169/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.3335 - loss: 779.5430 - reconstruction_loss: 776.2096 - val_kl_loss: 3.3807 - val_loss: 667.8751 - val_reconstruction_loss: 664.4943 - learning_rate: 4.9984e-04
# Epoch 170/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.3260 - loss: 779.2756 - reconstruction_loss: 775.9495 - val_kl_loss: 3.3227 - val_loss: 666.2314 - val_reconstruction_loss: 662.9087 - learning_rate: 4.9984e-04
# Epoch 171/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.3829 - loss: 779.2389 - reconstruction_loss: 775.8560 - val_kl_loss: 3.2501 - val_loss: 672.9871 - val_reconstruction_loss: 669.7369 - learning_rate: 4.9984e-04
# Epoch 172/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.3627 - loss: 779.0409 - reconstruction_loss: 775.6783 - val_kl_loss: 3.3882 - val_loss: 665.4520 - val_reconstruction_loss: 662.0637 - learning_rate: 4.9984e-04
# Epoch 173/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 3.3962 - loss: 779.2894 - reconstruction_loss: 775.8931 - val_kl_loss: 3.4277 - val_loss: 665.8948 - val_reconstruction_loss: 662.4672 - learning_rate: 4.9984e-04
# Epoch 174/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.4734 - loss: 777.7341 - reconstruction_loss: 774.2607 - val_kl_loss: 3.3819 - val_loss: 664.1362 - val_reconstruction_loss: 660.7543 - learning_rate: 4.9984e-04
# Epoch 175/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.4749 - loss: 776.8125 - reconstruction_loss: 773.3375 - val_kl_loss: 3.5131 - val_loss: 663.9447 - val_reconstruction_loss: 660.4316 - learning_rate: 4.9984e-04
# Epoch 176/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.5440 - loss: 776.7540 - reconstruction_loss: 773.2100 - val_kl_loss: 3.5651 - val_loss: 665.3340 - val_reconstruction_loss: 661.7689 - learning_rate: 4.9984e-04
# Epoch 177/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.5409 - loss: 777.2775 - reconstruction_loss: 773.7364 - val_kl_loss: 3.5451 - val_loss: 666.3124 - val_reconstruction_loss: 662.7673 - learning_rate: 4.9984e-04
# Epoch 178/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - kl_loss: 3.5388 - loss: 777.2587 - reconstruction_loss: 773.7200 - val_kl_loss: 3.5650 - val_loss: 665.2596 - val_reconstruction_loss: 661.6946 - learning_rate: 4.9984e-04
# Epoch 179/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.5438 - loss: 777.5660 - reconstruction_loss: 774.0221 - val_kl_loss: 3.5653 - val_loss: 663.5328 - val_reconstruction_loss: 659.9675 - learning_rate: 4.9984e-04
# Epoch 180/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 3.6124 - loss: 774.7285 - reconstruction_loss: 771.1163 - val_kl_loss: 3.5559 - val_loss: 662.8317 - val_reconstruction_loss: 659.2759 - learning_rate: 4.9984e-04
# Epoch 181/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.6243 - loss: 773.8790 - reconstruction_loss: 770.2546 - val_kl_loss: 3.6407 - val_loss: 664.8062 - val_reconstruction_loss: 661.1655 - learning_rate: 4.9984e-04
# Epoch 182/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.6908 - loss: 774.8875 - reconstruction_loss: 771.1967 - val_kl_loss: 3.6672 - val_loss: 665.1343 - val_reconstruction_loss: 661.4671 - learning_rate: 4.9984e-04
# Epoch 183/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - kl_loss: 3.6645 - loss: 775.1826 - reconstruction_loss: 771.5180 - val_kl_loss: 3.7010 - val_loss: 661.0388 - val_reconstruction_loss: 657.3378 - learning_rate: 4.9984e-04
# Epoch 184/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.7190 - loss: 773.0762 - reconstruction_loss: 769.3572 - val_kl_loss: 3.5920 - val_loss: 669.1852 - val_reconstruction_loss: 665.5931 - learning_rate: 4.9984e-04
# Epoch 185/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.6499 - loss: 776.6463 - reconstruction_loss: 772.9964 - val_kl_loss: 3.7437 - val_loss: 663.6204 - val_reconstruction_loss: 659.8767 - learning_rate: 4.9984e-04
# Epoch 186/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.7183 - loss: 773.1130 - reconstruction_loss: 769.3947 - val_kl_loss: 3.7808 - val_loss: 659.9139 - val_reconstruction_loss: 656.1332 - learning_rate: 4.9984e-04
# Epoch 187/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.8226 - loss: 771.9320 - reconstruction_loss: 768.1094 - val_kl_loss: 3.6801 - val_loss: 660.4286 - val_reconstruction_loss: 656.7485 - learning_rate: 4.9984e-04
# Epoch 188/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.7637 - loss: 772.0297 - reconstruction_loss: 768.2661 - val_kl_loss: 3.7895 - val_loss: 662.2087 - val_reconstruction_loss: 658.4193 - learning_rate: 4.9984e-04
# Epoch 189/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.8039 - loss: 772.4413 - reconstruction_loss: 768.6374 - val_kl_loss: 3.8914 - val_loss: 658.3648 - val_reconstruction_loss: 654.4734 - learning_rate: 4.9984e-04
# Epoch 190/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.8455 - loss: 770.5943 - reconstruction_loss: 766.7488 - val_kl_loss: 3.8645 - val_loss: 661.9727 - val_reconstruction_loss: 658.1082 - learning_rate: 4.9984e-04
# Epoch 191/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.8610 - loss: 770.3419 - reconstruction_loss: 766.4808 - val_kl_loss: 3.7894 - val_loss: 656.8880 - val_reconstruction_loss: 653.0986 - learning_rate: 4.9984e-04
# Epoch 192/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.8533 - loss: 769.9534 - reconstruction_loss: 766.1002 - val_kl_loss: 3.8761 - val_loss: 659.9948 - val_reconstruction_loss: 656.1187 - learning_rate: 4.9984e-04
# Epoch 193/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.8510 - loss: 770.1313 - reconstruction_loss: 766.2803 - val_kl_loss: 3.8813 - val_loss: 658.2173 - val_reconstruction_loss: 654.3361 - learning_rate: 4.9984e-04
# Epoch 194/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.8948 - loss: 770.0904 - reconstruction_loss: 766.1954 - val_kl_loss: 3.8820 - val_loss: 657.8135 - val_reconstruction_loss: 653.9315 - learning_rate: 4.9984e-04
# Epoch 195/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.8949 - loss: 768.4102 - reconstruction_loss: 764.5152 - val_kl_loss: 3.8339 - val_loss: 658.2588 - val_reconstruction_loss: 654.4249 - learning_rate: 4.9984e-04
# Epoch 196/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.9527 - loss: 768.6792 - reconstruction_loss: 764.7265 - val_kl_loss: 3.9614 - val_loss: 658.8775 - val_reconstruction_loss: 654.9161 - learning_rate: 4.9984e-04
# Epoch 197/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.9474 - loss: 767.9356 - reconstruction_loss: 763.9882 - val_kl_loss: 3.8670 - val_loss: 659.2449 - val_reconstruction_loss: 655.3779 - learning_rate: 4.9984e-04
# Epoch 198/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.9478 - loss: 766.6021 - reconstruction_loss: 762.6543 - val_kl_loss: 3.9491 - val_loss: 656.6562 - val_reconstruction_loss: 652.7072 - learning_rate: 4.9984e-04
# Epoch 199/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.9642 - loss: 767.8057 - reconstruction_loss: 763.8414 - val_kl_loss: 3.8924 - val_loss: 658.0845 - val_reconstruction_loss: 654.1921 - learning_rate: 4.9984e-04
# Epoch 200/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.9745 - loss: 766.1311 - reconstruction_loss: 762.1567 - val_kl_loss: 4.0098 - val_loss: 655.0438 - val_reconstruction_loss: 651.0339 - learning_rate: 4.9984e-04
# Epoch 201/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.0198 - loss: 765.6716 - reconstruction_loss: 761.6517 - val_kl_loss: 3.9455 - val_loss: 660.9291 - val_reconstruction_loss: 656.9836 - learning_rate: 4.9984e-04
# Epoch 202/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - kl_loss: 4.0008 - loss: 767.3408 - reconstruction_loss: 763.3401 - val_kl_loss: 3.9982 - val_loss: 654.8086 - val_reconstruction_loss: 650.8104 - learning_rate: 4.9984e-04
# Epoch 203/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.0488 - loss: 765.4144 - reconstruction_loss: 761.3657 - val_kl_loss: 3.9804 - val_loss: 657.2867 - val_reconstruction_loss: 653.3063 - learning_rate: 4.9984e-04
# Epoch 204/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.0738 - loss: 764.9930 - reconstruction_loss: 760.9192 - val_kl_loss: 4.1003 - val_loss: 655.4427 - val_reconstruction_loss: 651.3424 - learning_rate: 4.9984e-04
# Epoch 205/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.0920 - loss: 765.9838 - reconstruction_loss: 761.8918 - val_kl_loss: 4.0695 - val_loss: 660.4944 - val_reconstruction_loss: 656.4249 - learning_rate: 4.9984e-04
# Epoch 206/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.0939 - loss: 765.3115 - reconstruction_loss: 761.2175 - val_kl_loss: 4.0036 - val_loss: 660.3408 - val_reconstruction_loss: 656.3373 - learning_rate: 4.9984e-04
# Epoch 207/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.0923 - loss: 763.6794 - reconstruction_loss: 759.5870 - val_kl_loss: 4.0136 - val_loss: 661.3444 - val_reconstruction_loss: 657.3307 - learning_rate: 4.9984e-04
# Epoch 208/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.0733 - loss: 764.2040 - reconstruction_loss: 760.1307 - val_kl_loss: 4.0486 - val_loss: 657.3753 - val_reconstruction_loss: 653.3267 - learning_rate: 4.9984e-04
# Epoch 209/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.1031 - loss: 764.7973 - reconstruction_loss: 760.6942 - val_kl_loss: 4.1814 - val_loss: 657.4504 - val_reconstruction_loss: 653.2690 - learning_rate: 4.9984e-04
# Epoch 210/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.1713 - loss: 763.5296 - reconstruction_loss: 759.3583 - val_kl_loss: 4.0841 - val_loss: 652.0757 - val_reconstruction_loss: 647.9916 - learning_rate: 4.9984e-04
# Epoch 211/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.1482 - loss: 761.4222 - reconstruction_loss: 757.2740 - val_kl_loss: 4.1074 - val_loss: 651.7324 - val_reconstruction_loss: 647.6250 - learning_rate: 4.9984e-04
# Epoch 212/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 4.1353 - loss: 761.6568 - reconstruction_loss: 757.5215 - val_kl_loss: 4.0940 - val_loss: 657.2739 - val_reconstruction_loss: 653.1799 - learning_rate: 4.9984e-04
# Epoch 213/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.1681 - loss: 761.0636 - reconstruction_loss: 756.8955 - val_kl_loss: 4.1206 - val_loss: 656.1083 - val_reconstruction_loss: 651.9877 - learning_rate: 4.9984e-04
# Epoch 214/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - kl_loss: 4.1768 - loss: 762.6951 - reconstruction_loss: 758.5183 - val_kl_loss: 4.1318 - val_loss: 652.2945 - val_reconstruction_loss: 648.1627 - learning_rate: 4.9984e-04
# Epoch 215/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.2015 - loss: 763.6936 - reconstruction_loss: 759.4921 - val_kl_loss: 4.2208 - val_loss: 656.9049 - val_reconstruction_loss: 652.6841 - learning_rate: 4.9984e-04
# Epoch 216/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.2167 - loss: 764.4792 - reconstruction_loss: 760.2627 - val_kl_loss: 4.0884 - val_loss: 658.0215 - val_reconstruction_loss: 653.9331 - learning_rate: 4.9984e-04
# Epoch 217/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.2648 - loss: 767.4371 - reconstruction_loss: 763.1722 - val_kl_loss: 4.0926 - val_loss: 653.8431 - val_reconstruction_loss: 649.7505 - learning_rate: 4.9984e-04
# Epoch 218/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.2265 - loss: 762.7302 - reconstruction_loss: 758.5037 - val_kl_loss: 4.2272 - val_loss: 649.9979 - val_reconstruction_loss: 645.7707 - learning_rate: 4.9984e-04
# Epoch 219/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.2565 - loss: 759.0563 - reconstruction_loss: 754.7998 - val_kl_loss: 4.2478 - val_loss: 656.3156 - val_reconstruction_loss: 652.0677 - learning_rate: 4.9984e-04
# Epoch 220/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - kl_loss: 4.2941 - loss: 759.7488 - reconstruction_loss: 755.4547 - val_kl_loss: 4.1371 - val_loss: 651.5374 - val_reconstruction_loss: 647.4003 - learning_rate: 4.9984e-04
# Epoch 221/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.2029 - loss: 758.7418 - reconstruction_loss: 754.5388 - val_kl_loss: 4.1915 - val_loss: 650.2559 - val_reconstruction_loss: 646.0643 - learning_rate: 4.9984e-04
# Epoch 222/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.2427 - loss: 759.7205 - reconstruction_loss: 755.4778 - val_kl_loss: 4.2442 - val_loss: 654.3527 - val_reconstruction_loss: 650.1085 - learning_rate: 4.9984e-04
# Epoch 223/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.2677 - loss: 760.7709 - reconstruction_loss: 756.5032 - val_kl_loss: 4.2409 - val_loss: 655.3192 - val_reconstruction_loss: 651.0783 - learning_rate: 4.9984e-04
# Epoch 224/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.2766 - loss: 758.7415 - reconstruction_loss: 754.4648 - val_kl_loss: 4.1355 - val_loss: 651.7460 - val_reconstruction_loss: 647.6105 - learning_rate: 4.9984e-04
# Epoch 225/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.2329 - loss: 758.7545 - reconstruction_loss: 754.5215 - val_kl_loss: 4.1971 - val_loss: 653.1569 - val_reconstruction_loss: 648.9598 - learning_rate: 4.9984e-04
# Epoch 226/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.2662 - loss: 757.4242 - reconstruction_loss: 753.1580 - val_kl_loss: 4.2525 - val_loss: 652.0874 - val_reconstruction_loss: 647.8349 - learning_rate: 4.9984e-04
# Epoch 227/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.3172 - loss: 758.9719 - reconstruction_loss: 754.6548 - val_kl_loss: 4.2915 - val_loss: 650.3494 - val_reconstruction_loss: 646.0579 - learning_rate: 4.9984e-04
# Epoch 228/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.2975 - loss: 756.7311 - reconstruction_loss: 752.4337 - val_kl_loss: 4.2815 - val_loss: 655.2793 - val_reconstruction_loss: 650.9978 - learning_rate: 4.9984e-04
# Epoch 229/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.3022 - loss: 757.8788 - reconstruction_loss: 753.5766 - val_kl_loss: 4.2159 - val_loss: 650.2442 - val_reconstruction_loss: 646.0283 - learning_rate: 4.9984e-04
# Epoch 230/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.2842 - loss: 757.5004 - reconstruction_loss: 753.2162 - val_kl_loss: 4.2155 - val_loss: 651.2213 - val_reconstruction_loss: 647.0057 - learning_rate: 4.9984e-04
# Epoch 231/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.3410 - loss: 756.6513 - reconstruction_loss: 752.3103 - val_kl_loss: 4.2230 - val_loss: 648.6316 - val_reconstruction_loss: 644.4086 - learning_rate: 4.9984e-04
# Epoch 232/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.3306 - loss: 757.8298 - reconstruction_loss: 753.4991 - val_kl_loss: 4.2482 - val_loss: 649.1838 - val_reconstruction_loss: 644.9356 - learning_rate: 4.9984e-04
# Epoch 233/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.3149 - loss: 756.9901 - reconstruction_loss: 752.6753 - val_kl_loss: 4.2565 - val_loss: 649.9020 - val_reconstruction_loss: 645.6455 - learning_rate: 4.9984e-04
# Epoch 234/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.3105 - loss: 759.1948 - reconstruction_loss: 754.8843 - val_kl_loss: 4.2969 - val_loss: 646.6708 - val_reconstruction_loss: 642.3739 - learning_rate: 4.9984e-04
# Epoch 235/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.3678 - loss: 754.5254 - reconstruction_loss: 750.1575 - val_kl_loss: 4.2563 - val_loss: 646.4187 - val_reconstruction_loss: 642.1624 - learning_rate: 4.9984e-04
# Epoch 236/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.3518 - loss: 754.8781 - reconstruction_loss: 750.5263 - val_kl_loss: 4.2736 - val_loss: 648.2748 - val_reconstruction_loss: 644.0012 - learning_rate: 4.9984e-04
# Epoch 237/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.3303 - loss: 756.6396 - reconstruction_loss: 752.3093 - val_kl_loss: 4.3375 - val_loss: 645.9307 - val_reconstruction_loss: 641.5933 - learning_rate: 4.9984e-04
# Epoch 238/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.3882 - loss: 753.6396 - reconstruction_loss: 749.2513 - val_kl_loss: 4.3765 - val_loss: 649.5942 - val_reconstruction_loss: 645.2178 - learning_rate: 4.9984e-04
# Epoch 239/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.4152 - loss: 753.7748 - reconstruction_loss: 749.3596 - val_kl_loss: 4.5345 - val_loss: 645.8826 - val_reconstruction_loss: 641.3480 - learning_rate: 4.9984e-04
# Epoch 240/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.4928 - loss: 753.8110 - reconstruction_loss: 749.3182 - val_kl_loss: 4.3442 - val_loss: 648.4507 - val_reconstruction_loss: 644.1064 - learning_rate: 4.9984e-04
# Epoch 241/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.3970 - loss: 755.1791 - reconstruction_loss: 750.7822 - val_kl_loss: 4.3438 - val_loss: 645.2333 - val_reconstruction_loss: 640.8895 - learning_rate: 4.9984e-04
# Epoch 242/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.3960 - loss: 751.9584 - reconstruction_loss: 747.5623 - val_kl_loss: 4.4305 - val_loss: 653.5323 - val_reconstruction_loss: 649.1018 - learning_rate: 4.9984e-04
# Epoch 243/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.4517 - loss: 755.2493 - reconstruction_loss: 750.7977 - val_kl_loss: 4.3706 - val_loss: 642.6793 - val_reconstruction_loss: 638.3087 - learning_rate: 4.9984e-04
# Epoch 244/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.4501 - loss: 752.4971 - reconstruction_loss: 748.0470 - val_kl_loss: 4.3795 - val_loss: 648.6929 - val_reconstruction_loss: 644.3135 - learning_rate: 4.9984e-04
# Epoch 245/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.4580 - loss: 752.9702 - reconstruction_loss: 748.5123 - val_kl_loss: 4.4078 - val_loss: 645.6025 - val_reconstruction_loss: 641.1947 - learning_rate: 4.9984e-04
# Epoch 246/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.4610 - loss: 754.8181 - reconstruction_loss: 750.3570 - val_kl_loss: 4.5501 - val_loss: 645.7072 - val_reconstruction_loss: 641.1571 - learning_rate: 4.9984e-04
# Epoch 247/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.5164 - loss: 753.5418 - reconstruction_loss: 749.0254 - val_kl_loss: 4.4022 - val_loss: 645.5186 - val_reconstruction_loss: 641.1164 - learning_rate: 4.9984e-04
# Epoch 248/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.4498 - loss: 754.6788 - reconstruction_loss: 750.2290 - val_kl_loss: 4.4277 - val_loss: 654.5784 - val_reconstruction_loss: 650.1506 - learning_rate: 4.9984e-04
# Epoch 249/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - kl_loss: 4.5005 - loss: 753.0582 - reconstruction_loss: 748.5577 - val_kl_loss: 4.3024 - val_loss: 745.3116 - val_reconstruction_loss: 741.0092 - learning_rate: 4.9984e-04
# Epoch 250/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 2.2440 - loss: 825.0176 - reconstruction_loss: 822.7736 - val_kl_loss: 1.3125 - val_loss: 692.2127 - val_reconstruction_loss: 690.9003 - learning_rate: 4.9984e-04
# Epoch 251/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.4100 - loss: 808.9547 - reconstruction_loss: 807.5449 - val_kl_loss: 1.7795 - val_loss: 686.9978 - val_reconstruction_loss: 685.2183 - learning_rate: 4.9984e-04
# Epoch 252/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.8776 - loss: 802.8669 - reconstruction_loss: 800.9892 - val_kl_loss: 1.9235 - val_loss: 684.6573 - val_reconstruction_loss: 682.7339 - learning_rate: 4.9984e-04
# Epoch 253/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.9304 - loss: 800.6404 - reconstruction_loss: 798.7101 - val_kl_loss: 1.8543 - val_loss: 683.6730 - val_reconstruction_loss: 681.8187 - learning_rate: 4.9984e-04
# Epoch 254/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.9327 - loss: 799.3228 - reconstruction_loss: 797.3900 - val_kl_loss: 1.8760 - val_loss: 682.4874 - val_reconstruction_loss: 680.6113 - learning_rate: 4.9984e-04
# Epoch 255/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.9357 - loss: 798.1465 - reconstruction_loss: 796.2109 - val_kl_loss: 1.9153 - val_loss: 681.5081 - val_reconstruction_loss: 679.5928 - learning_rate: 4.9984e-04
# Epoch 256/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.9697 - loss: 796.9996 - reconstruction_loss: 795.0300 - val_kl_loss: 1.9852 - val_loss: 680.3359 - val_reconstruction_loss: 678.3506 - learning_rate: 4.9984e-04
# Epoch 257/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 1.9983 - loss: 796.0969 - reconstruction_loss: 794.0986 - val_kl_loss: 2.0720 - val_loss: 679.8129 - val_reconstruction_loss: 677.7408 - learning_rate: 4.9984e-04
# Epoch 258/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 2.0756 - loss: 795.3922 - reconstruction_loss: 793.3165 - val_kl_loss: 2.1351 - val_loss: 679.3313 - val_reconstruction_loss: 677.1962 - learning_rate: 4.9984e-04
# Epoch 259/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 2.1424 - loss: 794.6561 - reconstruction_loss: 792.5136 - val_kl_loss: 2.2266 - val_loss: 678.6520 - val_reconstruction_loss: 676.4254 - learning_rate: 4.9984e-04
# Epoch 260/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 2.2556 - loss: 793.8095 - reconstruction_loss: 791.5541 - val_kl_loss: 2.3272 - val_loss: 677.6441 - val_reconstruction_loss: 675.3169 - learning_rate: 4.9984e-04
# Epoch 261/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 2.4161 - loss: 792.7626 - reconstruction_loss: 790.3465 - val_kl_loss: 2.4817 - val_loss: 676.8244 - val_reconstruction_loss: 674.3427 - learning_rate: 4.9984e-04
# Epoch 262/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 2.5722 - loss: 791.2148 - reconstruction_loss: 788.6428 - val_kl_loss: 2.6103 - val_loss: 675.2985 - val_reconstruction_loss: 672.6882 - learning_rate: 4.9984e-04
# Epoch 263/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 2.7140 - loss: 789.3293 - reconstruction_loss: 786.6154 - val_kl_loss: 2.7605 - val_loss: 673.6666 - val_reconstruction_loss: 670.9061 - learning_rate: 4.9984e-04
# Epoch 264/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 2.8553 - loss: 787.4191 - reconstruction_loss: 784.5638 - val_kl_loss: 2.9012 - val_loss: 672.1132 - val_reconstruction_loss: 669.2120 - learning_rate: 4.9984e-04
# Epoch 265/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 2.9940 - loss: 785.9285 - reconstruction_loss: 782.9345 - val_kl_loss: 3.0221 - val_loss: 671.0127 - val_reconstruction_loss: 667.9906 - learning_rate: 4.9984e-04
# Epoch 266/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.1371 - loss: 784.5280 - reconstruction_loss: 781.3909 - val_kl_loss: 3.1726 - val_loss: 670.5965 - val_reconstruction_loss: 667.4240 - learning_rate: 4.9984e-04
# Epoch 267/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.2532 - loss: 782.9844 - reconstruction_loss: 779.7313 - val_kl_loss: 3.2865 - val_loss: 668.1290 - val_reconstruction_loss: 664.8425 - learning_rate: 4.9984e-04
# Epoch 268/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.4026 - loss: 781.1022 - reconstruction_loss: 777.6996 - val_kl_loss: 3.4109 - val_loss: 666.4633 - val_reconstruction_loss: 663.0524 - learning_rate: 4.9984e-04
# Epoch 269/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.4443 - loss: 780.6954 - reconstruction_loss: 777.2511 - val_kl_loss: 3.4282 - val_loss: 665.3597 - val_reconstruction_loss: 661.9315 - learning_rate: 4.9984e-04
# Epoch 270/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.5444 - loss: 778.0157 - reconstruction_loss: 774.4714 - val_kl_loss: 3.5547 - val_loss: 664.9279 - val_reconstruction_loss: 661.3732 - learning_rate: 4.9984e-04
# Epoch 271/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.5955 - loss: 777.8627 - reconstruction_loss: 774.2672 - val_kl_loss: 3.5871 - val_loss: 664.7302 - val_reconstruction_loss: 661.1431 - learning_rate: 4.9984e-04
# Epoch 272/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.6838 - loss: 775.9135 - reconstruction_loss: 772.2296 - val_kl_loss: 3.5728 - val_loss: 662.6968 - val_reconstruction_loss: 659.1240 - learning_rate: 4.9984e-04
# Epoch 273/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.7220 - loss: 774.6501 - reconstruction_loss: 770.9283 - val_kl_loss: 3.6910 - val_loss: 661.5419 - val_reconstruction_loss: 657.8508 - learning_rate: 4.9984e-04
# Epoch 274/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.8071 - loss: 773.7003 - reconstruction_loss: 769.8931 - val_kl_loss: 3.8025 - val_loss: 662.3879 - val_reconstruction_loss: 658.5853 - learning_rate: 4.9984e-04
# Epoch 275/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.8439 - loss: 774.2626 - reconstruction_loss: 770.4187 - val_kl_loss: 3.8163 - val_loss: 660.1799 - val_reconstruction_loss: 656.3636 - learning_rate: 4.9984e-04
# Epoch 276/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.9310 - loss: 771.6426 - reconstruction_loss: 767.7117 - val_kl_loss: 3.9623 - val_loss: 658.1149 - val_reconstruction_loss: 654.1526 - learning_rate: 4.9984e-04
# Epoch 277/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 3.9617 - loss: 771.2734 - reconstruction_loss: 767.3118 - val_kl_loss: 3.9290 - val_loss: 657.7765 - val_reconstruction_loss: 653.8475 - learning_rate: 4.9984e-04
# Epoch 278/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.0002 - loss: 768.7701 - reconstruction_loss: 764.7698 - val_kl_loss: 3.9605 - val_loss: 658.5204 - val_reconstruction_loss: 654.5598 - learning_rate: 4.9984e-04
# Epoch 279/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - kl_loss: 4.0558 - loss: 767.9214 - reconstruction_loss: 763.8658 - val_kl_loss: 4.0427 - val_loss: 658.6500 - val_reconstruction_loss: 654.6073 - learning_rate: 4.9984e-04
# Epoch 280/400
# 151/151 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - kl_loss: 4.0560 - loss: 767.6308 - reconstruction_loss: 763.5749
