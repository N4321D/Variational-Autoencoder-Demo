# %% [markdown]
# # AUTOENCODER DEMO
# Demo to show how autoencoders can be used to classify patterns in timeseries data
# This demo focusses especially on variational autoencoders
#
# It also is a great platform to play around with different parameters, layers,
# functions and architechtures and see how they affect the models learning

# %% [markdown]
# ## Imports and Setup

# %%
SEED = 85  # random seed

import numpy as np
from numpy.lib.stride_tricks import sliding_window_view
import os

# Plot imports
import holoviews as hv
import panel as pn
hv.extension('bokeh')
hv.renderer('bokeh').theme = 'dark_minimal'

# IMPORT ML libs and set random seeds
os.environ["KERAS_BACKEND"] = "tensorflow"    # set keras backend to tensorflow
import keras
from keras import ops
keras.utils.set_random_seed(SEED)  # set random seed for keras

import tensorflow as tf
tf.random.set_seed(SEED)
tf.config.experimental.enable_op_determinism()

from keras import backend as K
print(f"Backend: {K.backend()}")

from scipy import stats

# list avaiable gpus
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    print("Name:", gpu.name, " Type:", gpu.device_type)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="e26d4924-d818-44a3-b10e-9c2500dc7faf" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"018d119f-d6c2-47eb-9e52-12a52b3f579b":{"version":"3.4.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"0f81d13ee92d429091476d20b4b4c6f3","client_comm_id":"b81228cdfbb741e69671020c21b0aaa9"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"018d119f-d6c2-47eb-9e52-12a52b3f579b","roots":{"p1002":"e26d4924-d818-44a3-b10e-9c2500dc7faf"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# 2024-09-09 21:24:54.862420: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-09 21:24:54.884222: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-09 21:24:54.884278: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-09 21:24:54.885144: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-09 21:24:54.888932: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Backend: tensorflow
# Name: /physical_device:GPU:0  Type: GPU

# %%
def limit(x):
    # limits x between 0 and 1
    return (x - x.min()) / (x.max() - x.min())

# %% [markdown]
# ## GENERATE DATA
# Generate random timeseries patterns with specific frequencies in it.
# The patterns will repeat over the whole data set and noise will be added as well.
# Each pattern can have 1 or many features, thus each pattern that is detected can be a mix of multiple sub patterns.
# This simulates for example read-outs from multiple sensors that are recorded simultaneously.
#
# Parameters can be changed by changing the Singal Parameters here.

# %% [markdown]
# ### Signal Parameters & Globals

# %%
# SET PARAMETERS
N_PATTERNS = 30         # number of unique patterns to generate
REPEATS = 10            # how many times the patterns repeat in the total data set
SEQUENCE_LENGTH = 128   # sequence length of each pattern
N_FEATURES = 7          # number of features or input signal channels
NOISE_SIZE = 10000      # number of noise samples that are added
TIME_ENC_L = (1,)      # wavelengths (x * sequence len) in time encoder

TIME_BYPASS = False    # bypass time signal in encoder or not

# %% [markdown]
# ### Signal Generator Function
# This function generates each pattern. Below is an example of a pattern that is generated and contains 5 frequencies

# %%
def generate_signal(sample_rate=1000, duration=1.0, num_frequencies=5, freq_range=(1, 30), frequencies=None):
    """
    Generate a signal with given parameters.

    Parameters:
    sample_rate (int): The sample rate in samples per second.
    duration (float): The duration of the signal in seconds.
    num_frequencies (int): The number of unique frequencies in the signal.
    freq_range (tuple): The range of frequencies.

    Returns:
    t (numpy.ndarray): The time values for the samples.
    summed_signal (numpy.ndarray): The generated signal.
    """

    # Generate the time values for the samples
    t = np.arange(int(sample_rate * duration)) / sample_rate

    # Define the frequencies
    # frequencies = np.random.uniform(freq_range[0], freq_range[1], num_frequencies)
    if frequencies is None:
        frequencies = np.random.choice(np.linspace(*freq_range, num_frequencies * N_PATTERNS), num_frequencies, replace=False)
    generate_signal.frequencies = frequencies

    # Generate the signal
    signal = np.sin(2 * np.pi * frequencies[:, None] * t)

    # Sum the signal
    summed_signal = np.sum(signal, axis=0)

    return t, summed_signal
    
# Use the function to generate a signal
t, summed_signal = generate_signal(128, 1)

# Plot the signal
title = "Example signal with: " + ", ".join([f"{i:.2f}" for i in sorted(generate_signal.frequencies)]) + " Hz. signals"
pn.Row(hv.Curve((t, summed_signal)).opts(width=600, title=title, xlabel='time', ylabel='signal'))
# Out:
# Row
#     [0] HoloViews(Curve, height=300, sizing_mode='fixed', width=600)

# %% [markdown]
# ### Dataset Generation
# This function generates the full data set by creating N_PATTERN patterns of SEQUENCE_LENGTH sample points, that have N_FEATURES unique signals in each pattern.
# These are repeated REPEATS times and NOISE (NOISE_SIZE data points with random data, the size of the data window SEQUENCE_LENGTH) is added.
# Then a sliding window view is created and the patterns are randomized. There is also a time encoding added that has the values in TIME_ENC_L as period for cosine waves of the window length.
# Finally, labels are created for each sliding window. These labels have the number of the pattern that is most prominent in each window (using mode), or -1 if the window contains mainly noise.
# The some noise is added to all the data, and the dataset is split in validation and training data.

# %%
def make_dataset(seq_len, n_feat, n_patterns, repeats, noise_size, time_encoder_lengths, dtype='f4'):
    """
    Generates a dataset with specified patterns, noise, and time encoding.

    Parameters:
    seq_len (int): Length of each sequence.
    n_feat (int): Number of features in each sequence.
    n_patterns (int): Number of distinct patterns to generate.
    repeats (int): Number of times each pattern is repeated.
    noise_size (int): Number of noise sequences to add.
    time_encoder_lengths (list): List of lengths for the time encoder.
    dtype: np.dtype of output

    Returns:
    tuple: A tuple containing:
        - X (numpy.ndarray): The generated dataset with shape (total_sequences, seq_len, n_feat + 1).
        - labels (numpy.ndarray): The labels for each sequence with shape (total_sequences,).

    The function performs the following steps:
    1. Generates patterns and repeats them.
    2. Adds noise to the dataset.
    3. Limits the values between 0 and 1.
    4. Creates a time encoder and adds it to the dataset.
    5. Shuffles the dataset and applies a sliding window view.
    6. Creates labels for each pattern and noise.
    7. Adds noise to the dataset and limits the values again.

    Example usage:
    X, labels = make_dataset(100, 10, 5, 3, 50, [1, 2, 3])
    """
    X = np.tile(
        np.concatenate(
            [
                np.stack(
                    [generate_signal(seq_len, 1)[1] for i in range(n_feat)],
                    axis=1,
                )  # 1 pattern
                for ii in range(n_patterns)  # all patterns
            ]
        ),
        (repeats, 1),  # repeats
    )
    
    # add noise
    X = np.concatenate(
        [
            X,
            np.random.normal(X.mean(), X.std(), size=(noise_size, n_feat)),  # noise
        ],
        axis=0,
    ).astype(dtype)
       
    # limit  between 0 and 1
    X = limit(X) 

    # Create time encoder
    time_enc_data = np.zeros(X.shape[0]).astype(dtype)
    for i in time_encoder_lengths:
        time_enc_data += (0.5 * (np.cos(2 * i * np.pi * np.arange(X.shape[0]) / seq_len) + 1)).astype(dtype)

    # add time encoder
    X = np.concatenate((X, time_enc_data[:, np.newaxis]), axis=-1)
    idx = np.arange(X.shape[0])
    np.random.shuffle(idx)
    
    X = np.transpose(sliding_window_view(X, seq_len, axis=0), (0, 2, 1))
    
    # create shuffle index
    idx = np.arange(X.shape[0])
    np.random.shuffle(idx)

        
    # Create labels for each pattern and noise
    labels = np.concatenate(
        [np.concatenate([np.concatenate([np.full(seq_len, i) for i in range(n_patterns)]) for ii in range(repeats)]), # labels for patterns
         np.full(noise_size, -1)],  # label for noise
    )

    # make sliding window and select mode for each window
    labels = sliding_window_view(labels.astype('i2'), seq_len)
    labels = stats.mode(labels, axis=1).mode.squeeze().astype('i2')
    
    # Shuffle labels in the same way as X
    labels = labels[idx]
    X = X[idx]
    
    # add some noise
    x_std = X[:, :, :-1].std()
    noise_amp =  x_std / 4
    
    if not np.isfinite(noise_amp):
        # with f2 x.std -> np.inf
        noise_amp = 0.025

    X[:, :, :-1] += np.random.normal(-noise_amp / 2, noise_amp / 2, size=X[:, :, :-1].shape).astype(dtype)
    X = limit(X)
    
    return X, labels
    
X, labels = make_dataset(SEQUENCE_LENGTH, N_FEATURES, N_PATTERNS, REPEATS, NOISE_SIZE, TIME_ENC_L)
    
split = int(X.shape[0] * 0.8)
X, X_val = X[:split], X[split:]

labels, labels_val = labels[:split], labels[split:]

# %% [markdown]
# ## Build model
# The sample layer and combined model are based on this keras [example](https://keras.io/examples/generative/vae/)
#
# ### Variational Auto Encoder
# The variational autoencoder uses an encoder that projects the incoming data into 2 latent layers. One is used to project an mean (*z_mean*), the other to project a variation (*z_log_var*). The **sampling layer** uses these 2 values to send samples to the decoder that are sampled from a normal distribution based on the values in *z_mean* and *z_log_var*. The decoder then tries to reconstruct the data from these 2 values.
#
# The encoder uses convolutional layers to extract the features and patterns from the signal. The decoder uses a Dense layer to expand the incoming values from the latent space and then scales up the singal using convolutional transpose layers. Then the data goes through a GRU layer to reconstruct the signal. Both encoder and decoder employ multiheaded attention to emphasize the patterns.
#
# ***Time Bypass***
# The build model function has an option `time_bypass` that allows the time enconding to bypass the encoder and go straight to the decoder. This demonstrates that the encoder can learn patterns without the time encoding (which could be useful for model employment in situations where there is no time encoding available). Since we discard the decoder once the model is trained, it is ok to still pass the time encoding to the decorder (which helps it greatly to reconstruct the signals). Setting time_bypass to True demonstrates how the encoder still learns to detect patterns even if it is ingnorant about the timing, as long as the decoder can 'help it out' during training.

# %%
# Sampling layer for VAE
class Sampling(keras.layers.Layer):
    """
    Uses (z_mean, z_log_var) to sample z, 
    the vector encoding a digit.
    """

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.seed_generator = keras.random.SeedGenerator(SEED)

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = ops.shape(z_mean)[0]
        dim = ops.shape(z_mean)[1]
        epsilon = keras.random.normal(shape=(batch, dim), seed=self.seed_generator)
        return z_mean + ops.exp(0.5 * z_log_var) * epsilon

# %%
# VAE main model class
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]
    def compute_loss(self, data, training=True):
        if isinstance(data, tuple):
            data = data[0]
            
        z_mean, z_log_var, z = self.encoder(data)
        reconstruction = self.decoder(z)
        reconstruction_loss = ops.mean(
            ops.sum(
                keras.losses.mean_squared_error(data, reconstruction),
            )
        )
        kl_loss = -0.5 * (1 + z_log_var - ops.square(z_mean) - ops.exp(z_log_var))
        kl_loss = ops.mean(ops.sum(kl_loss, axis=1))
        total_loss = reconstruction_loss + kl_loss
        return total_loss, reconstruction_loss, kl_loss
    
    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        reconstruction = self.decoder(z)
        return reconstruction
    
    def train_step(self, data):
        with tf.GradientTape() as tape:
            total_loss, reconstruction_loss, kl_loss = self.compute_loss(data)
            grads = tape.gradient(total_loss, self.trainable_weights)
            self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
            
            self.total_loss_tracker.update_state(total_loss)
            self.reconstruction_loss_tracker.update_state(reconstruction_loss)
            self.kl_loss_tracker.update_state(kl_loss)
            return {
                "loss": self.total_loss_tracker.result(),
                "reconstruction_loss": self.reconstruction_loss_tracker.result(),
                "kl_loss": self.kl_loss_tracker.result(),
            }

    def test_step(self, data):
        total_loss, reconstruction_loss, kl_loss = self.compute_loss(data, training=False)
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": total_loss,
            "reconstruction_loss": reconstruction_loss,
            "kl_loss": kl_loss,
        }

# %%
# remove time enc
# X = X[:, :, :-1]
# X_val = X_val[:, :, :-1]

# %%
def build_model(
    seq_len,
    n_feat,
    conv_filts=32,
    time_bypass=False,
    num_heads=4,
    key_dims=8,
    scale_steps=4,
):
    latent_dim = 2  # Do not change -> will break cluster plot

    encoder_inputs = keras.Input(shape=(seq_len, n_feat))

    # split time trace from input data if time in encoder is disabled
    if time_bypass:
        x = encoder_inputs[:, :, :-1]
        time_enc = encoder_inputs[:, -1:, -1]
    else:
        x = encoder_inputs

    # Convulutional layers to detect patterns
    for n_filt in range(3):
        x = keras.layers.Conv1D(
            conv_filts,
            kernel_size=3,
            activation="relu",
            padding="same",
            strides=2,
        )(x)
        x = keras.layers.BatchNormalization()(x)

        # feature attention
        attention = keras.layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=key_dims
        )(x, x)
        attention = keras.layers.LayerNormalization(epsilon=1e-6)(attention)
        x = attention * x

    #  fully connected layer
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(n_feat, activation="relu")(x)

    # VAE part
    z_mean = keras.layers.Dense(latent_dim, name="z_mean")(x)
    z_log_var = keras.layers.Dense(latent_dim, name="z_log_var")(x)
    z = Sampling(name="bottleneck")([z_mean, z_log_var])

    # pass time encoding to decoder if not encoded in the encoder
    if time_bypass:
        z = keras.layers.Concatenate()([z, time_enc])

    vae_encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
    vae_encoder.summary()

    # DECODER
    latent_inputs = keras.Input(
        shape=(vae_encoder.output[-1].shape[-1],), name="decoder_input"
    )

    x = keras.layers.Dense(
        8 * latent_inputs.shape[-1],
        activation="relu",
        name=f"decoder_expand",
    )(latent_inputs)

    # scale up signal to original dimensions
    _shape_mp = int(seq_len / (2 ** scale_steps))
    x = keras.layers.Reshape((_shape_mp, x.shape[-1] // _shape_mp))(x)

    for i in range(scale_steps):
        x = keras.layers.Conv1DTranspose(
            conv_filts, kernel_size=3, strides=2, activation="relu", padding="same"
        )(x)
        x = keras.layers.BatchNormalization()(x)

    # GRU
    x = keras.layers.GRU(n_feat * 16, return_sequences=True)(x)

    # Output attention:
    attention = keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=key_dims)(
        x, x
    )
    attention = keras.layers.LayerNormalization(epsilon=1e-6)(attention)
    x = x * attention

    # output
    x = keras.layers.Conv1D(n_feat, kernel_size=5, activation="relu", padding="same")(x)

    decoder_outputs = x
    decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
    decoder.summary()

    return vae_encoder, decoder


vae_encoder, decoder = build_model(
    X.shape[1], 
    X.shape[2],
    conv_filts=16, 
    time_bypass=TIME_BYPASS,
)
# Out:
# 2024-09-09 21:24:57.794221: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14150 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 8)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 64, 16)    │        400 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64, 16)    │         64 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 64, 16)    │      2,160 │ batch_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 64, 16)    │         32 │ multi_head_atten… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 64, 16)    │          0 │ layer_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 32, 16)    │        784 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 16)    │         64 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 32, 16)    │      2,160 │ batch_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 32, 16)    │         32 │ multi_head_atten… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 32, 16)    │          0 │ layer_normalizat… │
# │ (Multiply)          │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 16, 16)    │        784 │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16)    │         64 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 16, 16)    │      2,160 │ batch_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 16, 16)    │         32 │ multi_head_atten… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 16, 16)    │          0 │ layer_normalizat… │
# │ (Multiply)          │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 256)       │          0 │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 8)         │      2,056 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean (Dense)      │ (None, 2)         │         18 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var (Dense)   │ (None, 2)         │         18 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bottleneck          │ (None, 2)         │          0 │ z_mean[0][0],     │
# │ (Sampling)          │                   │            │ z_log_var[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 10,828 (42.30 KB)
#  Trainable params: 10,732 (41.92 KB)
#  Non-trainable params: 96 (384.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ decoder_input       │ (None, 2)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_expand      │ (None, 16)        │         48 │ decoder_input[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 8, 2)      │          0 │ decoder_expand[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_transpose    │ (None, 16, 16)    │        112 │ reshape[0][0]     │
# │ (Conv1DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16)    │         64 │ conv1d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_transpose_1  │ (None, 32, 16)    │        784 │ batch_normalizat… │
# │ (Conv1DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 16)    │         64 │ conv1d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_transpose_2  │ (None, 64, 16)    │        784 │ batch_normalizat… │
# │ (Conv1DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 16)    │         64 │ conv1d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_transpose_3  │ (None, 128, 16)   │        784 │ batch_normalizat… │
# │ (Conv1DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 16)   │         64 │ conv1d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru (GRU)           │ (None, 128, 128)  │     56,064 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 128, 128)  │     16,608 │ gru[0][0],        │
# │ (MultiHeadAttentio… │                   │            │ gru[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 128)  │        256 │ multi_head_atten… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 128, 128)  │          0 │ gru[0][0],        │
# │ (Multiply)          │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 128, 8)    │      5,128 │ multiply_3[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 80,824 (315.72 KB)
#  Trainable params: 80,696 (315.22 KB)
#  Non-trainable params: 128 (512.00 B)

# %%
# from keras.utils import plot_model
# plot_model(vae_encoder, rankdir='TD',to_file='encoder_bypass.png', show_layer_activations=True, show_shapes=True)
# plot_model(decoder, rankdir='TD',to_file='decoder_bypass.png', show_layer_activations=True, show_shapes=True)

# %%
model = VAE(vae_encoder, decoder)
model.compile(optimizer=keras.optimizers.AdamW(learning_rate=1e-3))

# %%
encoder = keras.Model(vae_encoder.input, vae_encoder.get_layer("z_mean").output)

# %% [markdown]
# ## Training
# Here the traing functions and callbacks are defined, for this demo, there is nothing you have to change. In case you are interested here is a short summary of all functions and callbacks:
# - learning rate schedulure: reduce learning rate after the 60th epoch
# - Loss and Live sample plot: plots the loss after each epoch and plots the performance of the full model (the decoder output) over the target validation data to visualize how the model performs
# - Encoder Live plot: plots the z_mean space after each epoch on a number of validation data points to show how the latent space evolves over training
#
# **Please Note**:
# - There is a user warning to force a stop in execution if running all cells. This is because the live plots only work if there is a little interruption. To run this demo you have to *manually run* the last cell where the `train(.....)` function is called, after the plots show.
# - It takes around 100 epochs for clusters to show with `time_bypass` disabled and around 400 epochs to show clusters with `time_bypass` enabled

# %%
callbacks = []

# %%
# learning rate scheduler
def scheduler(epoch, lr):        
    if lr < 1e-4:
        return lr
        
    if epoch > 300:
        return lr * 0.99

    else: # steady lr
        return lr

lr_cb = keras.callbacks.LearningRateScheduler(scheduler)
#callbacks.append(lr_cb)

# %%
colors = [
    "#FFB300", "#803E75", "#FF6800", "#A6BDD7", "#C1FF20", "#CEA262", "#817066",
    "#007D34", "#F6768E", "#00538A", "#FF7A5C", "#53377A", "#FF8E00", "#B32851",
    "#F4C800", "#7F180D", "#93AA00", "#593315", "#F13A13", "#99FF99", "#FF6E76",
    "#1770A4", "#23AAFF", "#A1CAF1", "#C2B280", "#967BB6", "#CAE0AB", "#CE00FF",
    "#F2F3F4", "#848482", "#008856"
]

# %%
# LIVE PLOTS DEFINED HERE
from holoviews import streams


class EncPlotCallback(keras.callbacks.Callback):
    def __init__(self, encoder, data, labels=None):
        self.data = data
        self.labels = (
            labels if labels is not None else np.ones(data.shape[0], dtype="i4")
        )
        self.encoder = encoder
        self.encode_data()
        self.encoded_stream = streams.Buffer(
            data={"x": self.encoded_data[:, 0], "y": self.encoded_data[:, 1]},
            length=data.shape[0],
        )
        self.plot_enc = hv.DynamicMap(self.encoded_plot, streams=[self.encoded_stream])

    def encode_data(self):
        self.encoded_data = self.encoder.predict(self.data, batch_size=512, verbose=0)

    def on_epoch_end(self, epoch, logs={}):
        self.encode_data()
        self.encoded_stream.send(
            {
                "x": self.encoded_data[:, 0],
                "y": self.encoded_data[:, 1],
            }
        )

    def encoded_plot(self, data):
        xlim = data["x"].min(), data["x"].max()
        ylim = data["y"].min(), data["y"].max()
        mask = self.labels[: data["x"].shape[0]] != -1

        # plot data
        fig = hv.Scatter(
            (
                data["x"][mask],
                data["y"][mask],
                self.labels[: data["x"].shape[0]][mask],
            ),
            vdims=["y", "labels"],
        ).opts(
            size=2,
            color="labels",
            cmap=colors[1:],  # "category20",
            alpha=0.7,
            show_legend=False,
        )

        # plot noise
        fig = fig * hv.Scatter(
            (
                data["x"][~mask],
                data["y"][~mask],
                self.labels[: data["x"].shape[0]][~mask],
            ),
            vdims=["y", "labels"],
            label="noise",
        ).opts(
            size=2,
            color="red",
            alpha=0.7,
            xlim=xlim,
            ylim=ylim,
        )
        return fig.opts(
            width=600,
            height=400,
            title="encoded data",
            shared_axes=False,
        )

    def show_figs(self):
        return self.plot_enc




class LivePlotCallBack(keras.callbacks.Callback):
    def __init__(self, model, x_val, y_val=None, pars=[], plot_opts={}, batch_size=32, loss_par="loss", val_loss_par="val_loss"):
        # Define the plot
        self.loss_par = loss_par
        self.val_loss_par = val_loss_par
        self.epoch = -1
        self.pars = pars
        self.mod = model
        self.x_val = x_val
        self.y_val = y_val
        self.y_pred = np.zeros_like(self.y_val)
        self.plot_opts =  {"width": 300 if self.y_val.shape[1] != 1 else 600,
                            "xlabel": "",
                            "height": 300,
                          }
        self.plot_opts.update(plot_opts)
        self.batch_size = batch_size

        # Define the streams
        self.stream = streams.Buffer(
            data=dict(epoch=np.array([]), loss=np.array([]), val_loss=np.array([])),
            length=10000,
        )

        self.sample_stream = streams.Pipe([])

        # create plots
        self.plot_samp = hv.DynamicMap(self.sample_plot, streams=[self.sample_stream])
        self.plot_loss = hv.DynamicMap(self.loss_plot, streams=[self.stream])

        self.trigger_sample()  # force plot


    # Define the plots
    def sample_plot(self, data):
        epoch = 'untrained'
        if self.epoch >= 0:
            epoch = self.epoch

        y = self.y_val #data.get("y", np.array([]))
        y_pred = self.y_pred #data.get("y_pred", np.array([]))

        # Create a plot of validation vs prediction
        _figs  = []
        if y.shape[1] == 1:
            # make a time trace of all predictions (batchsize is x axis)
            for feature in range(self.y_pred.shape[-1]):
                _figs.append(
                    (hv.Curve(y[:, 0, feature]).relabel("val y")
                    * hv.Curve(y_pred[:, 0, feature]).relabel("pred y")
                ).opts(
                    title=f"{feature}: {self.pars[feature] if self.pars else 'feature ' + str(feature)}",  
                    **self.plot_opts
                ))
        else:
            # plot over sequence length on x axis
            for sample in range(y.shape[0]):
                for i in range(y.shape[-1]):
                    _figs.append(
                        (
                            hv.Curve(y[sample, :, i]).relabel("val y")
                            * hv.Curve(y_pred[sample, :, i])
                            .relabel("pred y")
                        ).opts(
                            title=f"{sample}: {self.pars[i] if self.pars else 'feature ' + str(i)}",  
                            **self.plot_opts
                        )
                    )
            
        fig = hv.Layout(_figs).cols(4).opts(title=f"Sample prediction:", shared_axes=False) 
        
        return fig

    def loss_plot(self, data):
        epoch, loss, val_loss = "untrained", "", ""
        
        if data["epoch"].size > 0:
            epoch = int(data["epoch"][-1]) + 1
            loss = round(data.get('loss', [0])[-1], 4)
            val_loss = round(data.get('val_loss', [0])[-1], 4)


        return hv.Curve(
            (data["epoch"] + 1, data["loss"]), "Epoch", "Loss", label=self.loss_par
        ).opts(width=600, 
               title=f"Live loss plot (epoch: {epoch}, loss: {loss}, val_loss: {val_loss})",
               color='limegreen',
              ) * hv.Curve(
            (data["epoch"] + 1, data["val_loss"]), "Epoch", "Loss", label=self.val_loss_par
        ).opts(color='red')

    def on_epoch_end(self, epoch, logs={}):
        self.last_logs = logs
        self.epoch = epoch
        self.do_loss(epoch, logs.get(self.loss_par, np.nan), logs.get(self.val_loss_par, np.nan))
        self.trigger_sample()

    def do_loss(self, epoch, loss, val_loss):
        self.stream.send(
            {
                "epoch": np.array([epoch]),
                "loss": np.array([loss]),
                "val_loss": np.array([val_loss]),
            }
        )

    def trigger_sample(self):
        if self.epoch >= 0:
            self.y_pred = self.mod.predict(self.x_val, verbose=0, batch_size=self.batch_size)
        self.sample_stream.send(True)  # send fake data to trigger figure refresh

    def show_figs(
        self,
    ):
        return pn.Column(self.plot_loss, self.plot_samp)

# %%
first_data_idx = (labels >= 0).argmax()  # use argmin to find first non noise point
cb = LivePlotCallBack(
    model,
    X_val[[first_data_idx]],
    X_val[[first_data_idx]],
    batch_size=128,
    loss_par="loss",
    val_loss_par="val_loss",
    pars=[f"Signal {i}" for i in range(N_FEATURES)] + ["time_enc"],
)
enc_cb = EncPlotCallback(encoder, X_val, labels_val)

callbacks.extend([cb, enc_cb])
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1725917098.727968  147957 service.cc:145] XLA service 0x588160a6eb20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1725917098.728028  147957 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 3080 Ti Laptop GPU, Compute Capability 8.6
# 2024-09-09 21:24:58.741984: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-09-09 21:24:58.805438: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# I0000 00:00:1725917099.574442  147957 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %%
def train(**kwargs):
    model.fit(
        X,
        validation_data=X_val,
        callbacks=callbacks,
        **kwargs
    )


pn.Column(
    pn.Row(
        cb.plot_loss.opts(height=400),
        enc_cb.show_figs().opts(title="Z_mean Latent Dimension"),
    ),
    cb.plot_samp,
)
# Out:
# Column
#     [0] Row
#         [0] HoloViews(DynamicMap, height=400, sizing_mode='fixed', width=600)
#         [1] HoloViews(DynamicMap, height=400, sizing_mode='fixed', width=600)
#     [1] HoloViews(DynamicMap)

# %%
# The warning raised here is to stop execution of the code until the image is loaded. If you run the next cell immediately the image will not update. 
# Please wait until you see the image and then manually run the next cell with the train function

raise UserWarning("Force stop here to give live image time to load, please run next cell manually after image is loaded")
# Out:
# ---------------------------------------------------------------------------
# UserWarning                               Traceback (most recent call last)
# Cell In[19], line 4
#       1 # The warning raised here is to stop execution of the code until the image is loaded. If you run the next cell immediately the image will not update.
#       2 # Please wait until you see the image and then manually run the next cell with the train function
# ----> 4 raise UserWarning("Force stop here to give live image time to load, please run next cell manually after image is loaded")
#
# UserWarning: Force stop here to give live image time to load, please run next cell manually after image is loaded

# %%
# %%time
train(batch_size=256, epochs=325 if TIME_BYPASS else 400, verbose=2)
# Out:
# Epoch 1/400
# 151/151 - 12s - 82ms/step - kl_loss: 1.0345 - loss: 1182.3346 - reconstruction_loss: 1181.3002 - val_kl_loss: 3.2233 - val_loss: 545.4672 - val_reconstruction_loss: 542.2439
# Epoch 2/400
# 151/151 - 5s - 32ms/step - kl_loss: 10.2022 - loss: 582.8889 - reconstruction_loss: 572.6865 - val_kl_loss: 12.4140 - val_loss: 267.3983 - val_reconstruction_loss: 254.9843
# Epoch 3/400
# 151/151 - 5s - 32ms/step - kl_loss: 10.1136 - loss: 329.7970 - reconstruction_loss: 319.6833 - val_kl_loss: 8.9941 - val_loss: 226.5334 - val_reconstruction_loss: 217.5393
# Epoch 4/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.5020 - loss: 311.7998 - reconstruction_loss: 303.2977 - val_kl_loss: 8.2376 - val_loss: 222.3152 - val_reconstruction_loss: 214.0776
# Epoch 5/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.9904 - loss: 308.3405 - reconstruction_loss: 300.3501 - val_kl_loss: 7.7891 - val_loss: 220.5689 - val_reconstruction_loss: 212.7798
# Epoch 6/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.6883 - loss: 305.9561 - reconstruction_loss: 298.2678 - val_kl_loss: 7.6092 - val_loss: 219.3653 - val_reconstruction_loss: 211.7561
# Epoch 7/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.4615 - loss: 304.2630 - reconstruction_loss: 296.8015 - val_kl_loss: 7.5304 - val_loss: 218.5207 - val_reconstruction_loss: 210.9903
# Epoch 8/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.3531 - loss: 303.1591 - reconstruction_loss: 295.8061 - val_kl_loss: 7.4359 - val_loss: 217.6346 - val_reconstruction_loss: 210.1987
# Epoch 9/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.2639 - loss: 301.8680 - reconstruction_loss: 294.6041 - val_kl_loss: 7.2844 - val_loss: 216.2651 - val_reconstruction_loss: 208.9807
# Epoch 10/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.1976 - loss: 300.8267 - reconstruction_loss: 293.6292 - val_kl_loss: 7.2325 - val_loss: 215.5438 - val_reconstruction_loss: 208.3113
# Epoch 11/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.1223 - loss: 299.7812 - reconstruction_loss: 292.6589 - val_kl_loss: 7.1186 - val_loss: 215.1808 - val_reconstruction_loss: 208.0622
# Epoch 12/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.0566 - loss: 299.2494 - reconstruction_loss: 292.1927 - val_kl_loss: 7.1113 - val_loss: 214.7134 - val_reconstruction_loss: 207.6021
# Epoch 13/400
# 151/151 - 5s - 33ms/step - kl_loss: 7.0154 - loss: 298.6450 - reconstruction_loss: 291.6295 - val_kl_loss: 7.0207 - val_loss: 214.2500 - val_reconstruction_loss: 207.2293
# Epoch 14/400
# 151/151 - 5s - 32ms/step - kl_loss: 6.9745 - loss: 298.5346 - reconstruction_loss: 291.5600 - val_kl_loss: 7.0456 - val_loss: 214.2181 - val_reconstruction_loss: 207.1725
# Epoch 15/400
# 151/151 - 5s - 32ms/step - kl_loss: 6.9316 - loss: 298.3751 - reconstruction_loss: 291.4436 - val_kl_loss: 6.9761 - val_loss: 213.9747 - val_reconstruction_loss: 206.9986
# Epoch 16/400
# 151/151 - 5s - 32ms/step - kl_loss: 6.8684 - loss: 297.8318 - reconstruction_loss: 290.9634 - val_kl_loss: 6.8909 - val_loss: 213.8256 - val_reconstruction_loss: 206.9347
# Epoch 17/400
# 151/151 - 5s - 32ms/step - kl_loss: 6.8392 - loss: 297.6429 - reconstruction_loss: 290.8038 - val_kl_loss: 6.8853 - val_loss: 213.9296 - val_reconstruction_loss: 207.0443
# Epoch 18/400
# 151/151 - 5s - 32ms/step - kl_loss: 6.7975 - loss: 297.6848 - reconstruction_loss: 290.8874 - val_kl_loss: 6.9205 - val_loss: 214.0380 - val_reconstruction_loss: 207.1175
# Epoch 19/400
# 151/151 - 5s - 32ms/step - kl_loss: 6.7617 - loss: 297.4216 - reconstruction_loss: 290.6599 - val_kl_loss: 6.7536 - val_loss: 213.4957 - val_reconstruction_loss: 206.7421
# Epoch 20/400
# 151/151 - 5s - 31ms/step - kl_loss: 6.7213 - loss: 297.2253 - reconstruction_loss: 290.5040 - val_kl_loss: 6.7595 - val_loss: 213.4993 - val_reconstruction_loss: 206.7398
# Epoch 21/400
# 151/151 - 5s - 33ms/step - kl_loss: 6.6893 - loss: 297.1604 - reconstruction_loss: 290.4710 - val_kl_loss: 6.8035 - val_loss: 213.4996 - val_reconstruction_loss: 206.6960
# Epoch 22/400
# 151/151 - 5s - 32ms/step - kl_loss: 6.6383 - loss: 296.9284 - reconstruction_loss: 290.2901 - val_kl_loss: 6.6331 - val_loss: 213.1754 - val_reconstruction_loss: 206.5423
# Epoch 23/400
# 151/151 - 5s - 32ms/step - kl_loss: 6.6085 - loss: 296.8425 - reconstruction_loss: 290.2339 - val_kl_loss: 6.6046 - val_loss: 213.6344 - val_reconstruction_loss: 207.0298
# Epoch 24/400
# 151/151 - 5s - 33ms/step - kl_loss: 6.5719 - loss: 296.4490 - reconstruction_loss: 289.8771 - val_kl_loss: 6.5014 - val_loss: 212.9338 - val_reconstruction_loss: 206.4324
# Epoch 25/400
# 151/151 - 5s - 32ms/step - kl_loss: 6.5606 - loss: 296.3479 - reconstruction_loss: 289.7873 - val_kl_loss: 6.5729 - val_loss: 212.4543 - val_reconstruction_loss: 205.8814
# Epoch 26/400
# 151/151 - 5s - 33ms/step - kl_loss: 6.5210 - loss: 296.0229 - reconstruction_loss: 289.5018 - val_kl_loss: 6.6693 - val_loss: 212.6412 - val_reconstruction_loss: 205.9719
# Epoch 27/400
# 151/151 - 5s - 33ms/step - kl_loss: 6.4901 - loss: 295.7666 - reconstruction_loss: 289.2765 - val_kl_loss: 6.5763 - val_loss: 212.3387 - val_reconstruction_loss: 205.7625
# Epoch 28/400
# 151/151 - 5s - 33ms/step - kl_loss: 6.5204 - loss: 295.6874 - reconstruction_loss: 289.1670 - val_kl_loss: 6.8863 - val_loss: 213.0549 - val_reconstruction_loss: 206.1686
# Epoch 29/400
# 151/151 - 5s - 32ms/step - kl_loss: 6.5425 - loss: 294.8603 - reconstruction_loss: 288.3178 - val_kl_loss: 6.7471 - val_loss: 211.9185 - val_reconstruction_loss: 205.1714
# Epoch 30/400
# 151/151 - 5s - 32ms/step - kl_loss: 6.5964 - loss: 294.5414 - reconstruction_loss: 287.9452 - val_kl_loss: 6.6738 - val_loss: 211.5891 - val_reconstruction_loss: 204.9153
# Epoch 31/400
# 151/151 - 5s - 33ms/step - kl_loss: 6.6489 - loss: 294.0085 - reconstruction_loss: 287.3596 - val_kl_loss: 6.7248 - val_loss: 210.9812 - val_reconstruction_loss: 204.2563
# Epoch 32/400
# 151/151 - 5s - 32ms/step - kl_loss: 6.7031 - loss: 293.4052 - reconstruction_loss: 286.7021 - val_kl_loss: 6.7774 - val_loss: 210.9215 - val_reconstruction_loss: 204.1441
# Epoch 33/400
# 151/151 - 5s - 32ms/step - kl_loss: 6.7448 - loss: 292.9850 - reconstruction_loss: 286.2401 - val_kl_loss: 6.7358 - val_loss: 211.6680 - val_reconstruction_loss: 204.9322
# Epoch 34/400
# 151/151 - 5s - 32ms/step - kl_loss: 6.7439 - loss: 292.8921 - reconstruction_loss: 286.1482 - val_kl_loss: 6.7869 - val_loss: 209.8114 - val_reconstruction_loss: 203.0245
# Epoch 35/400
# 151/151 - 5s - 31ms/step - kl_loss: 6.7683 - loss: 292.7368 - reconstruction_loss: 285.9685 - val_kl_loss: 6.7403 - val_loss: 210.1103 - val_reconstruction_loss: 203.3700
# Epoch 36/400
# 151/151 - 5s - 31ms/step - kl_loss: 6.7751 - loss: 292.9528 - reconstruction_loss: 286.1777 - val_kl_loss: 6.8097 - val_loss: 209.9731 - val_reconstruction_loss: 203.1635
# Epoch 37/400
# 151/151 - 5s - 31ms/step - kl_loss: 6.8601 - loss: 292.2322 - reconstruction_loss: 285.3721 - val_kl_loss: 7.0522 - val_loss: 209.2801 - val_reconstruction_loss: 202.2279
# Epoch 38/400
# 151/151 - 5s - 31ms/step - kl_loss: 6.8942 - loss: 292.2626 - reconstruction_loss: 285.3683 - val_kl_loss: 6.9897 - val_loss: 209.1006 - val_reconstruction_loss: 202.1109
# Epoch 39/400
# 151/151 - 5s - 32ms/step - kl_loss: 6.9518 - loss: 291.7463 - reconstruction_loss: 284.7944 - val_kl_loss: 7.0288 - val_loss: 208.8695 - val_reconstruction_loss: 201.8407
# Epoch 40/400
# 151/151 - 5s - 32ms/step - kl_loss: 6.9339 - loss: 291.7360 - reconstruction_loss: 284.8020 - val_kl_loss: 7.0490 - val_loss: 208.6141 - val_reconstruction_loss: 201.5651
# Epoch 41/400
# 151/151 - 5s - 32ms/step - kl_loss: 6.9906 - loss: 291.4890 - reconstruction_loss: 284.4985 - val_kl_loss: 7.1255 - val_loss: 208.9048 - val_reconstruction_loss: 201.7793
# Epoch 42/400
# 151/151 - 5s - 31ms/step - kl_loss: 6.9520 - loss: 291.9138 - reconstruction_loss: 284.9619 - val_kl_loss: 7.0633 - val_loss: 209.1089 - val_reconstruction_loss: 202.0456
# Epoch 43/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.0686 - loss: 291.1985 - reconstruction_loss: 284.1299 - val_kl_loss: 7.0608 - val_loss: 209.1548 - val_reconstruction_loss: 202.0939
# Epoch 44/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.1097 - loss: 290.6226 - reconstruction_loss: 283.5128 - val_kl_loss: 7.0649 - val_loss: 210.5217 - val_reconstruction_loss: 203.4568
# Epoch 45/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.1704 - loss: 290.2430 - reconstruction_loss: 283.0726 - val_kl_loss: 7.1385 - val_loss: 208.6052 - val_reconstruction_loss: 201.4666
# Epoch 46/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.2869 - loss: 289.5932 - reconstruction_loss: 282.3063 - val_kl_loss: 7.5879 - val_loss: 206.8873 - val_reconstruction_loss: 199.2994
# Epoch 47/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.3647 - loss: 288.7460 - reconstruction_loss: 281.3813 - val_kl_loss: 7.4793 - val_loss: 209.4824 - val_reconstruction_loss: 202.0031
# Epoch 48/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.4350 - loss: 288.4615 - reconstruction_loss: 281.0264 - val_kl_loss: 7.5152 - val_loss: 207.0707 - val_reconstruction_loss: 199.5555
# Epoch 49/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.4661 - loss: 287.8517 - reconstruction_loss: 280.3855 - val_kl_loss: 7.5695 - val_loss: 206.0856 - val_reconstruction_loss: 198.5161
# Epoch 50/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.4937 - loss: 287.6072 - reconstruction_loss: 280.1135 - val_kl_loss: 7.6503 - val_loss: 207.3247 - val_reconstruction_loss: 199.6744
# Epoch 51/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.4983 - loss: 287.4062 - reconstruction_loss: 279.9080 - val_kl_loss: 7.4182 - val_loss: 207.8039 - val_reconstruction_loss: 200.3857
# Epoch 52/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.5250 - loss: 286.9788 - reconstruction_loss: 279.4538 - val_kl_loss: 7.5494 - val_loss: 206.4744 - val_reconstruction_loss: 198.9250
# Epoch 53/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.5591 - loss: 286.6985 - reconstruction_loss: 279.1395 - val_kl_loss: 7.6430 - val_loss: 205.4318 - val_reconstruction_loss: 197.7888
# Epoch 54/400
# 151/151 - 5s - 30ms/step - kl_loss: 7.5927 - loss: 286.2700 - reconstruction_loss: 278.6772 - val_kl_loss: 7.5142 - val_loss: 207.4221 - val_reconstruction_loss: 199.9079
# Epoch 55/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.5454 - loss: 286.5421 - reconstruction_loss: 278.9967 - val_kl_loss: 7.7473 - val_loss: 206.9175 - val_reconstruction_loss: 199.1703
# Epoch 56/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.5854 - loss: 285.9242 - reconstruction_loss: 278.3387 - val_kl_loss: 7.6521 - val_loss: 205.2694 - val_reconstruction_loss: 197.6173
# Epoch 57/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.5898 - loss: 286.0227 - reconstruction_loss: 278.4329 - val_kl_loss: 7.6376 - val_loss: 205.7912 - val_reconstruction_loss: 198.1536
# Epoch 58/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.5383 - loss: 286.3598 - reconstruction_loss: 278.8214 - val_kl_loss: 7.6955 - val_loss: 205.4420 - val_reconstruction_loss: 197.7465
# Epoch 59/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.6065 - loss: 285.4822 - reconstruction_loss: 277.8758 - val_kl_loss: 7.6081 - val_loss: 206.4615 - val_reconstruction_loss: 198.8534
# Epoch 60/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.5481 - loss: 286.0616 - reconstruction_loss: 278.5134 - val_kl_loss: 7.6081 - val_loss: 205.4840 - val_reconstruction_loss: 197.8759
# Epoch 61/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.6106 - loss: 285.3140 - reconstruction_loss: 277.7035 - val_kl_loss: 7.6746 - val_loss: 205.4990 - val_reconstruction_loss: 197.8243
# Epoch 62/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.6319 - loss: 285.2283 - reconstruction_loss: 277.5963 - val_kl_loss: 7.5398 - val_loss: 206.9490 - val_reconstruction_loss: 199.4092
# Epoch 63/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.5855 - loss: 285.5408 - reconstruction_loss: 277.9552 - val_kl_loss: 7.6299 - val_loss: 207.4352 - val_reconstruction_loss: 199.8053
# Epoch 64/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.6033 - loss: 285.1353 - reconstruction_loss: 277.5320 - val_kl_loss: 7.7153 - val_loss: 206.5571 - val_reconstruction_loss: 198.8417
# Epoch 65/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.6170 - loss: 285.0858 - reconstruction_loss: 277.4688 - val_kl_loss: 7.8851 - val_loss: 205.1176 - val_reconstruction_loss: 197.2325
# Epoch 66/400
# 151/151 - 5s - 33ms/step - kl_loss: 7.6222 - loss: 284.9954 - reconstruction_loss: 277.3733 - val_kl_loss: 7.7273 - val_loss: 205.1689 - val_reconstruction_loss: 197.4416
# Epoch 67/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.6313 - loss: 284.7959 - reconstruction_loss: 277.1646 - val_kl_loss: 7.6781 - val_loss: 204.8198 - val_reconstruction_loss: 197.1417
# Epoch 68/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.6167 - loss: 284.9232 - reconstruction_loss: 277.3065 - val_kl_loss: 7.6145 - val_loss: 205.1508 - val_reconstruction_loss: 197.5363
# Epoch 69/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.5917 - loss: 285.1533 - reconstruction_loss: 277.5616 - val_kl_loss: 7.7212 - val_loss: 204.8688 - val_reconstruction_loss: 197.1476
# Epoch 70/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.6597 - loss: 284.4319 - reconstruction_loss: 276.7723 - val_kl_loss: 7.7636 - val_loss: 205.2693 - val_reconstruction_loss: 197.5057
# Epoch 71/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.5846 - loss: 285.2662 - reconstruction_loss: 277.6816 - val_kl_loss: 7.6017 - val_loss: 204.4328 - val_reconstruction_loss: 196.8311
# Epoch 72/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.6786 - loss: 284.3981 - reconstruction_loss: 276.7195 - val_kl_loss: 7.7860 - val_loss: 204.2189 - val_reconstruction_loss: 196.4330
# Epoch 73/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.7006 - loss: 284.0292 - reconstruction_loss: 276.3286 - val_kl_loss: 7.8330 - val_loss: 204.2146 - val_reconstruction_loss: 196.3815
# Epoch 74/400
# 151/151 - 5s - 30ms/step - kl_loss: 7.7085 - loss: 284.2289 - reconstruction_loss: 276.5204 - val_kl_loss: 7.7799 - val_loss: 204.3568 - val_reconstruction_loss: 196.5769
# Epoch 75/400
# 151/151 - 5s - 33ms/step - kl_loss: 7.6733 - loss: 284.4378 - reconstruction_loss: 276.7645 - val_kl_loss: 7.7106 - val_loss: 204.4883 - val_reconstruction_loss: 196.7777
# Epoch 76/400
# 151/151 - 5s - 33ms/step - kl_loss: 7.6934 - loss: 284.5011 - reconstruction_loss: 276.8077 - val_kl_loss: 7.7297 - val_loss: 204.4458 - val_reconstruction_loss: 196.7161
# Epoch 77/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.7780 - loss: 283.5975 - reconstruction_loss: 275.8196 - val_kl_loss: 7.8803 - val_loss: 203.9219 - val_reconstruction_loss: 196.0415
# Epoch 78/400
# 151/151 - 5s - 33ms/step - kl_loss: 7.7784 - loss: 283.5872 - reconstruction_loss: 275.8087 - val_kl_loss: 7.9143 - val_loss: 204.0809 - val_reconstruction_loss: 196.1667
# Epoch 79/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.7867 - loss: 283.5383 - reconstruction_loss: 275.7516 - val_kl_loss: 7.9384 - val_loss: 204.0952 - val_reconstruction_loss: 196.1568
# Epoch 80/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.7976 - loss: 283.4442 - reconstruction_loss: 275.6467 - val_kl_loss: 7.7614 - val_loss: 203.9413 - val_reconstruction_loss: 196.1799
# Epoch 81/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.7872 - loss: 283.5211 - reconstruction_loss: 275.7338 - val_kl_loss: 7.9470 - val_loss: 204.2696 - val_reconstruction_loss: 196.3225
# Epoch 82/400
# 151/151 - 5s - 33ms/step - kl_loss: 7.8121 - loss: 283.0931 - reconstruction_loss: 275.2810 - val_kl_loss: 8.0142 - val_loss: 203.4844 - val_reconstruction_loss: 195.4702
# Epoch 83/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.8510 - loss: 282.8582 - reconstruction_loss: 275.0072 - val_kl_loss: 8.0296 - val_loss: 203.8927 - val_reconstruction_loss: 195.8631
# Epoch 84/400
# 151/151 - 5s - 33ms/step - kl_loss: 7.8598 - loss: 283.0191 - reconstruction_loss: 275.1592 - val_kl_loss: 7.9336 - val_loss: 204.3225 - val_reconstruction_loss: 196.3889
# Epoch 85/400
# 151/151 - 5s - 33ms/step - kl_loss: 7.7771 - loss: 283.6680 - reconstruction_loss: 275.8910 - val_kl_loss: 7.9550 - val_loss: 203.4177 - val_reconstruction_loss: 195.4627
# Epoch 86/400
# 151/151 - 5s - 33ms/step - kl_loss: 7.8823 - loss: 282.5714 - reconstruction_loss: 274.6891 - val_kl_loss: 8.0014 - val_loss: 203.7845 - val_reconstruction_loss: 195.7831
# Epoch 87/400
# 151/151 - 5s - 33ms/step - kl_loss: 7.8971 - loss: 282.4948 - reconstruction_loss: 274.5977 - val_kl_loss: 7.8985 - val_loss: 204.6795 - val_reconstruction_loss: 196.7810
# Epoch 88/400
# 151/151 - 5s - 33ms/step - kl_loss: 7.8890 - loss: 282.4819 - reconstruction_loss: 274.5930 - val_kl_loss: 7.9047 - val_loss: 203.2683 - val_reconstruction_loss: 195.3636
# Epoch 89/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.8635 - loss: 283.0649 - reconstruction_loss: 275.2014 - val_kl_loss: 8.0096 - val_loss: 204.0267 - val_reconstruction_loss: 196.0172
# Epoch 90/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.9258 - loss: 282.1230 - reconstruction_loss: 274.1972 - val_kl_loss: 8.2092 - val_loss: 203.1213 - val_reconstruction_loss: 194.9121
# Epoch 91/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.8212 - loss: 283.4015 - reconstruction_loss: 275.5803 - val_kl_loss: 8.6560 - val_loss: 204.8621 - val_reconstruction_loss: 196.2061
# Epoch 92/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.8957 - loss: 282.5949 - reconstruction_loss: 274.6993 - val_kl_loss: 8.1567 - val_loss: 203.3303 - val_reconstruction_loss: 195.1736
# Epoch 93/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.9456 - loss: 281.8845 - reconstruction_loss: 273.9389 - val_kl_loss: 8.2438 - val_loss: 203.4453 - val_reconstruction_loss: 195.2015
# Epoch 94/400
# 151/151 - 5s - 31ms/step - kl_loss: 7.8975 - loss: 282.6872 - reconstruction_loss: 274.7897 - val_kl_loss: 8.0836 - val_loss: 202.8785 - val_reconstruction_loss: 194.7949
# Epoch 95/400
# 151/151 - 5s - 34ms/step - kl_loss: 7.8863 - loss: 282.2591 - reconstruction_loss: 274.3729 - val_kl_loss: 8.0773 - val_loss: 203.0603 - val_reconstruction_loss: 194.9830
# Epoch 96/400
# 151/151 - 5s - 34ms/step - kl_loss: 7.8873 - loss: 282.5633 - reconstruction_loss: 274.6761 - val_kl_loss: 8.0614 - val_loss: 202.7649 - val_reconstruction_loss: 194.7035
# Epoch 97/400
# 151/151 - 5s - 33ms/step - kl_loss: 7.9388 - loss: 281.9513 - reconstruction_loss: 274.0125 - val_kl_loss: 8.1453 - val_loss: 203.5287 - val_reconstruction_loss: 195.3834
# Epoch 98/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.9470 - loss: 281.7125 - reconstruction_loss: 273.7655 - val_kl_loss: 8.1513 - val_loss: 202.5283 - val_reconstruction_loss: 194.3770
# Epoch 99/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.8893 - loss: 282.7699 - reconstruction_loss: 274.8806 - val_kl_loss: 7.9756 - val_loss: 202.8304 - val_reconstruction_loss: 194.8547
# Epoch 100/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.9662 - loss: 281.4256 - reconstruction_loss: 273.4594 - val_kl_loss: 8.1576 - val_loss: 202.2950 - val_reconstruction_loss: 194.1374
# Epoch 101/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.0140 - loss: 281.3713 - reconstruction_loss: 273.3572 - val_kl_loss: 8.0614 - val_loss: 202.4586 - val_reconstruction_loss: 194.3971
# Epoch 102/400
# 151/151 - 5s - 32ms/step - kl_loss: 7.9788 - loss: 281.7354 - reconstruction_loss: 273.7566 - val_kl_loss: 8.0374 - val_loss: 201.9762 - val_reconstruction_loss: 193.9388
# Epoch 103/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.0153 - loss: 281.4132 - reconstruction_loss: 273.3979 - val_kl_loss: 8.2089 - val_loss: 202.6448 - val_reconstruction_loss: 194.4359
# Epoch 104/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.0680 - loss: 280.7950 - reconstruction_loss: 272.7271 - val_kl_loss: 8.2352 - val_loss: 201.5735 - val_reconstruction_loss: 193.3383
# Epoch 105/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.0836 - loss: 280.9001 - reconstruction_loss: 272.8165 - val_kl_loss: 8.2716 - val_loss: 202.0100 - val_reconstruction_loss: 193.7384
# Epoch 106/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.0274 - loss: 281.3537 - reconstruction_loss: 273.3263 - val_kl_loss: 8.1071 - val_loss: 201.8261 - val_reconstruction_loss: 193.7190
# Epoch 107/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.0722 - loss: 280.7143 - reconstruction_loss: 272.6420 - val_kl_loss: 8.3904 - val_loss: 202.2480 - val_reconstruction_loss: 193.8576
# Epoch 108/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.1153 - loss: 280.1269 - reconstruction_loss: 272.0116 - val_kl_loss: 8.2197 - val_loss: 201.7072 - val_reconstruction_loss: 193.4875
# Epoch 109/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.1467 - loss: 279.8195 - reconstruction_loss: 271.6729 - val_kl_loss: 8.2031 - val_loss: 200.9115 - val_reconstruction_loss: 192.7084
# Epoch 110/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.1682 - loss: 279.6028 - reconstruction_loss: 271.4346 - val_kl_loss: 8.3986 - val_loss: 202.3406 - val_reconstruction_loss: 193.9420
# Epoch 111/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.1281 - loss: 280.1635 - reconstruction_loss: 272.0353 - val_kl_loss: 8.3355 - val_loss: 200.8166 - val_reconstruction_loss: 192.4812
# Epoch 112/400
# 151/151 - 5s - 36ms/step - kl_loss: 8.1903 - loss: 279.3298 - reconstruction_loss: 271.1394 - val_kl_loss: 8.3839 - val_loss: 201.0673 - val_reconstruction_loss: 192.6834
# Epoch 113/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.1628 - loss: 279.5917 - reconstruction_loss: 271.4290 - val_kl_loss: 8.4082 - val_loss: 201.2633 - val_reconstruction_loss: 192.8551
# Epoch 114/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.2040 - loss: 279.0009 - reconstruction_loss: 270.7969 - val_kl_loss: 8.2960 - val_loss: 200.2283 - val_reconstruction_loss: 191.9323
# Epoch 115/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.1986 - loss: 278.7838 - reconstruction_loss: 270.5851 - val_kl_loss: 8.4359 - val_loss: 200.2739 - val_reconstruction_loss: 191.8380
# Epoch 116/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.1371 - loss: 279.7016 - reconstruction_loss: 271.5645 - val_kl_loss: 8.3333 - val_loss: 199.9247 - val_reconstruction_loss: 191.5914
# Epoch 117/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.1950 - loss: 278.3622 - reconstruction_loss: 270.1673 - val_kl_loss: 8.4277 - val_loss: 199.6497 - val_reconstruction_loss: 191.2220
# Epoch 118/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.2693 - loss: 277.7001 - reconstruction_loss: 269.4308 - val_kl_loss: 8.4293 - val_loss: 199.1010 - val_reconstruction_loss: 190.6716
# Epoch 119/400
# 151/151 - 5s - 31ms/step - kl_loss: 8.2655 - loss: 277.8380 - reconstruction_loss: 269.5724 - val_kl_loss: 8.4142 - val_loss: 198.9000 - val_reconstruction_loss: 190.4858
# Epoch 120/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.2640 - loss: 277.4563 - reconstruction_loss: 269.1924 - val_kl_loss: 8.6356 - val_loss: 199.9543 - val_reconstruction_loss: 191.3188
# Epoch 121/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.2545 - loss: 277.9370 - reconstruction_loss: 269.6826 - val_kl_loss: 8.3519 - val_loss: 200.1768 - val_reconstruction_loss: 191.8248
# Epoch 122/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.3164 - loss: 276.9089 - reconstruction_loss: 268.5925 - val_kl_loss: 8.4530 - val_loss: 198.3290 - val_reconstruction_loss: 189.8760
# Epoch 123/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.3196 - loss: 276.8431 - reconstruction_loss: 268.5235 - val_kl_loss: 8.3953 - val_loss: 198.3626 - val_reconstruction_loss: 189.9673
# Epoch 124/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.2634 - loss: 276.9214 - reconstruction_loss: 268.6580 - val_kl_loss: 8.5127 - val_loss: 198.0110 - val_reconstruction_loss: 189.4984
# Epoch 125/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.3281 - loss: 276.4941 - reconstruction_loss: 268.1661 - val_kl_loss: 8.5209 - val_loss: 197.7647 - val_reconstruction_loss: 189.2438
# Epoch 126/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.3630 - loss: 275.8419 - reconstruction_loss: 267.4789 - val_kl_loss: 8.5152 - val_loss: 197.5695 - val_reconstruction_loss: 189.0544
# Epoch 127/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.3548 - loss: 275.9146 - reconstruction_loss: 267.5598 - val_kl_loss: 8.3914 - val_loss: 199.5283 - val_reconstruction_loss: 191.1369
# Epoch 128/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.3487 - loss: 275.3323 - reconstruction_loss: 266.9837 - val_kl_loss: 8.5508 - val_loss: 197.6348 - val_reconstruction_loss: 189.0839
# Epoch 129/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.3705 - loss: 275.1917 - reconstruction_loss: 266.8212 - val_kl_loss: 8.5333 - val_loss: 197.0997 - val_reconstruction_loss: 188.5663
# Epoch 130/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.3839 - loss: 274.5369 - reconstruction_loss: 266.1529 - val_kl_loss: 8.6100 - val_loss: 196.8974 - val_reconstruction_loss: 188.2874
# Epoch 131/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.3744 - loss: 275.1829 - reconstruction_loss: 266.8085 - val_kl_loss: 8.5364 - val_loss: 197.5260 - val_reconstruction_loss: 188.9896
# Epoch 132/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.4329 - loss: 274.1720 - reconstruction_loss: 265.7391 - val_kl_loss: 8.4224 - val_loss: 198.1413 - val_reconstruction_loss: 189.7189
# Epoch 133/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.4102 - loss: 274.0281 - reconstruction_loss: 265.6180 - val_kl_loss: 8.5008 - val_loss: 196.5918 - val_reconstruction_loss: 188.0910
# Epoch 134/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.4114 - loss: 273.0411 - reconstruction_loss: 264.6299 - val_kl_loss: 8.5606 - val_loss: 197.1486 - val_reconstruction_loss: 188.5880
# Epoch 135/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.4615 - loss: 273.4339 - reconstruction_loss: 264.9724 - val_kl_loss: 8.6158 - val_loss: 196.5850 - val_reconstruction_loss: 187.9692
# Epoch 136/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.4710 - loss: 273.0049 - reconstruction_loss: 264.5339 - val_kl_loss: 8.6590 - val_loss: 196.2874 - val_reconstruction_loss: 187.6284
# Epoch 137/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.4604 - loss: 272.6890 - reconstruction_loss: 264.2285 - val_kl_loss: 8.5087 - val_loss: 195.6091 - val_reconstruction_loss: 187.1004
# Epoch 138/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.4812 - loss: 272.1298 - reconstruction_loss: 263.6487 - val_kl_loss: 8.6225 - val_loss: 195.2961 - val_reconstruction_loss: 186.6737
# Epoch 139/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.4455 - loss: 272.8303 - reconstruction_loss: 264.3847 - val_kl_loss: 8.5073 - val_loss: 194.5323 - val_reconstruction_loss: 186.0250
# Epoch 140/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.4986 - loss: 270.9990 - reconstruction_loss: 262.5004 - val_kl_loss: 8.6388 - val_loss: 194.6077 - val_reconstruction_loss: 185.9689
# Epoch 141/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.4467 - loss: 272.3627 - reconstruction_loss: 263.9160 - val_kl_loss: 8.6301 - val_loss: 194.1029 - val_reconstruction_loss: 185.4727
# Epoch 142/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.5119 - loss: 271.0386 - reconstruction_loss: 262.5267 - val_kl_loss: 8.6424 - val_loss: 193.6425 - val_reconstruction_loss: 185.0002
# Epoch 143/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.5008 - loss: 271.3343 - reconstruction_loss: 262.8335 - val_kl_loss: 8.5899 - val_loss: 194.6361 - val_reconstruction_loss: 186.0462
# Epoch 144/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.5682 - loss: 270.5292 - reconstruction_loss: 261.9609 - val_kl_loss: 8.5978 - val_loss: 196.4188 - val_reconstruction_loss: 187.8210
# Epoch 145/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.5881 - loss: 269.9509 - reconstruction_loss: 261.3627 - val_kl_loss: 8.7035 - val_loss: 192.8786 - val_reconstruction_loss: 184.1751
# Epoch 146/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.5700 - loss: 269.8244 - reconstruction_loss: 261.2545 - val_kl_loss: 8.5746 - val_loss: 192.6200 - val_reconstruction_loss: 184.0455
# Epoch 147/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.5878 - loss: 269.1086 - reconstruction_loss: 260.5208 - val_kl_loss: 8.7494 - val_loss: 192.6062 - val_reconstruction_loss: 183.8568
# Epoch 148/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.5948 - loss: 268.8210 - reconstruction_loss: 260.2262 - val_kl_loss: 8.6177 - val_loss: 192.0073 - val_reconstruction_loss: 183.3896
# Epoch 149/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.6199 - loss: 269.0338 - reconstruction_loss: 260.4139 - val_kl_loss: 8.5920 - val_loss: 194.1969 - val_reconstruction_loss: 185.6049
# Epoch 150/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.6067 - loss: 268.1120 - reconstruction_loss: 259.5055 - val_kl_loss: 8.7556 - val_loss: 191.9849 - val_reconstruction_loss: 183.2293
# Epoch 151/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.6171 - loss: 267.9918 - reconstruction_loss: 259.3747 - val_kl_loss: 8.7352 - val_loss: 191.0372 - val_reconstruction_loss: 182.3019
# Epoch 152/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.6526 - loss: 267.5605 - reconstruction_loss: 258.9080 - val_kl_loss: 8.7779 - val_loss: 193.5207 - val_reconstruction_loss: 184.7428
# Epoch 153/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.6583 - loss: 267.6842 - reconstruction_loss: 259.0260 - val_kl_loss: 8.8365 - val_loss: 191.4794 - val_reconstruction_loss: 182.6429
# Epoch 154/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.7081 - loss: 266.1208 - reconstruction_loss: 257.4127 - val_kl_loss: 8.7973 - val_loss: 190.8911 - val_reconstruction_loss: 182.0937
# Epoch 155/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.6649 - loss: 266.4130 - reconstruction_loss: 257.7481 - val_kl_loss: 8.7469 - val_loss: 189.4417 - val_reconstruction_loss: 180.6948
# Epoch 156/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.7161 - loss: 265.9087 - reconstruction_loss: 257.1925 - val_kl_loss: 8.9108 - val_loss: 190.0892 - val_reconstruction_loss: 181.1784
# Epoch 157/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.7404 - loss: 265.7668 - reconstruction_loss: 257.0263 - val_kl_loss: 8.7360 - val_loss: 190.1672 - val_reconstruction_loss: 181.4312
# Epoch 158/400
# 151/151 - 5s - 36ms/step - kl_loss: 8.7255 - loss: 264.9797 - reconstruction_loss: 256.2542 - val_kl_loss: 8.9274 - val_loss: 189.3642 - val_reconstruction_loss: 180.4367
# Epoch 159/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.7665 - loss: 265.4887 - reconstruction_loss: 256.7222 - val_kl_loss: 8.7938 - val_loss: 193.1475 - val_reconstruction_loss: 184.3538
# Epoch 160/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.7858 - loss: 264.3951 - reconstruction_loss: 255.6093 - val_kl_loss: 8.8591 - val_loss: 188.1403 - val_reconstruction_loss: 179.2812
# Epoch 161/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.7246 - loss: 265.8893 - reconstruction_loss: 257.1648 - val_kl_loss: 8.8600 - val_loss: 189.7165 - val_reconstruction_loss: 180.8565
# Epoch 162/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.7991 - loss: 263.4795 - reconstruction_loss: 254.6804 - val_kl_loss: 8.8777 - val_loss: 187.5154 - val_reconstruction_loss: 178.6377
# Epoch 163/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.7858 - loss: 263.2958 - reconstruction_loss: 254.5100 - val_kl_loss: 8.9598 - val_loss: 188.6531 - val_reconstruction_loss: 179.6934
# Epoch 164/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.8255 - loss: 263.1329 - reconstruction_loss: 254.3074 - val_kl_loss: 8.9388 - val_loss: 188.0599 - val_reconstruction_loss: 179.1211
# Epoch 165/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.8471 - loss: 262.1645 - reconstruction_loss: 253.3175 - val_kl_loss: 8.9369 - val_loss: 188.5634 - val_reconstruction_loss: 179.6264
# Epoch 166/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.8494 - loss: 262.8194 - reconstruction_loss: 253.9700 - val_kl_loss: 8.9442 - val_loss: 186.7851 - val_reconstruction_loss: 177.8409
# Epoch 167/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.8204 - loss: 262.5044 - reconstruction_loss: 253.6840 - val_kl_loss: 9.0185 - val_loss: 188.0971 - val_reconstruction_loss: 179.0786
# Epoch 168/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.8741 - loss: 262.4011 - reconstruction_loss: 253.5270 - val_kl_loss: 9.1733 - val_loss: 187.8049 - val_reconstruction_loss: 178.6317
# Epoch 169/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.9058 - loss: 261.8794 - reconstruction_loss: 252.9735 - val_kl_loss: 8.9256 - val_loss: 188.7225 - val_reconstruction_loss: 179.7969
# Epoch 170/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.9222 - loss: 261.5005 - reconstruction_loss: 252.5785 - val_kl_loss: 9.0802 - val_loss: 188.2523 - val_reconstruction_loss: 179.1720
# Epoch 171/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.9331 - loss: 260.6455 - reconstruction_loss: 251.7125 - val_kl_loss: 8.9103 - val_loss: 193.6018 - val_reconstruction_loss: 184.6915
# Epoch 172/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.9433 - loss: 260.4838 - reconstruction_loss: 251.5405 - val_kl_loss: 9.0160 - val_loss: 191.0166 - val_reconstruction_loss: 182.0006
# Epoch 173/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.9274 - loss: 260.6987 - reconstruction_loss: 251.7713 - val_kl_loss: 9.0305 - val_loss: 187.0281 - val_reconstruction_loss: 177.9976
# Epoch 174/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.9448 - loss: 260.3528 - reconstruction_loss: 251.4079 - val_kl_loss: 8.9531 - val_loss: 190.1594 - val_reconstruction_loss: 181.2063
# Epoch 175/400
# 151/151 - 5s - 33ms/step - kl_loss: 8.9562 - loss: 259.6238 - reconstruction_loss: 250.6677 - val_kl_loss: 9.0102 - val_loss: 189.0136 - val_reconstruction_loss: 180.0034
# Epoch 176/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.9706 - loss: 259.4999 - reconstruction_loss: 250.5294 - val_kl_loss: 8.9945 - val_loss: 188.1297 - val_reconstruction_loss: 179.1351
# Epoch 177/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.9805 - loss: 259.7396 - reconstruction_loss: 250.7591 - val_kl_loss: 9.2139 - val_loss: 185.0967 - val_reconstruction_loss: 175.8828
# Epoch 178/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.9820 - loss: 259.1226 - reconstruction_loss: 250.1406 - val_kl_loss: 9.1675 - val_loss: 188.2917 - val_reconstruction_loss: 179.1242
# Epoch 179/400
# 151/151 - 5s - 32ms/step - kl_loss: 8.9789 - loss: 259.5886 - reconstruction_loss: 250.6097 - val_kl_loss: 9.0750 - val_loss: 183.8784 - val_reconstruction_loss: 174.8034
# Epoch 180/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.0144 - loss: 257.6887 - reconstruction_loss: 248.6743 - val_kl_loss: 9.2887 - val_loss: 183.7434 - val_reconstruction_loss: 174.4547
# Epoch 181/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.0645 - loss: 257.2298 - reconstruction_loss: 248.1653 - val_kl_loss: 9.2262 - val_loss: 185.2310 - val_reconstruction_loss: 176.0049
# Epoch 182/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.0548 - loss: 258.0191 - reconstruction_loss: 248.9643 - val_kl_loss: 9.2548 - val_loss: 186.4503 - val_reconstruction_loss: 177.1954
# Epoch 183/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.0901 - loss: 256.7608 - reconstruction_loss: 247.6708 - val_kl_loss: 9.0873 - val_loss: 189.2314 - val_reconstruction_loss: 180.1441
# Epoch 184/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.0717 - loss: 257.2982 - reconstruction_loss: 248.2265 - val_kl_loss: 9.1427 - val_loss: 185.6464 - val_reconstruction_loss: 176.5036
# Epoch 185/400
# 151/151 - 5s - 33ms/step - kl_loss: 9.0880 - loss: 256.2965 - reconstruction_loss: 247.2085 - val_kl_loss: 9.3165 - val_loss: 183.6711 - val_reconstruction_loss: 174.3545
# Epoch 186/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.0795 - loss: 255.2969 - reconstruction_loss: 246.2173 - val_kl_loss: 9.2596 - val_loss: 182.5841 - val_reconstruction_loss: 173.3244
# Epoch 187/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.1105 - loss: 256.3216 - reconstruction_loss: 247.2110 - val_kl_loss: 9.3470 - val_loss: 184.6979 - val_reconstruction_loss: 175.3509
# Epoch 188/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.1238 - loss: 254.9672 - reconstruction_loss: 245.8434 - val_kl_loss: 9.3682 - val_loss: 184.4368 - val_reconstruction_loss: 175.0686
# Epoch 189/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.1287 - loss: 255.7768 - reconstruction_loss: 246.6479 - val_kl_loss: 9.2124 - val_loss: 186.3546 - val_reconstruction_loss: 177.1421
# Epoch 190/400
# 151/151 - 5s - 33ms/step - kl_loss: 9.1498 - loss: 255.3814 - reconstruction_loss: 246.2314 - val_kl_loss: 9.3942 - val_loss: 180.7231 - val_reconstruction_loss: 171.3289
# Epoch 191/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.1899 - loss: 253.7714 - reconstruction_loss: 244.5816 - val_kl_loss: 9.3146 - val_loss: 183.0003 - val_reconstruction_loss: 173.6857
# Epoch 192/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.1524 - loss: 255.8558 - reconstruction_loss: 246.7033 - val_kl_loss: 9.3405 - val_loss: 184.9354 - val_reconstruction_loss: 175.5948
# Epoch 193/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.1824 - loss: 253.5744 - reconstruction_loss: 244.3920 - val_kl_loss: 9.2828 - val_loss: 185.1562 - val_reconstruction_loss: 175.8733
# Epoch 194/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.1930 - loss: 254.5247 - reconstruction_loss: 245.3317 - val_kl_loss: 9.3256 - val_loss: 183.2283 - val_reconstruction_loss: 173.9026
# Epoch 195/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.1933 - loss: 253.2831 - reconstruction_loss: 244.0898 - val_kl_loss: 9.3757 - val_loss: 179.0161 - val_reconstruction_loss: 169.6404
# Epoch 196/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.2164 - loss: 253.5199 - reconstruction_loss: 244.3035 - val_kl_loss: 9.4821 - val_loss: 181.7419 - val_reconstruction_loss: 172.2598
# Epoch 197/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.2570 - loss: 251.4368 - reconstruction_loss: 242.1798 - val_kl_loss: 9.4141 - val_loss: 184.5512 - val_reconstruction_loss: 175.1371
# Epoch 198/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.2375 - loss: 251.6867 - reconstruction_loss: 242.4491 - val_kl_loss: 9.4422 - val_loss: 180.3817 - val_reconstruction_loss: 170.9395
# Epoch 199/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.2335 - loss: 252.3887 - reconstruction_loss: 243.1552 - val_kl_loss: 9.3067 - val_loss: 184.0249 - val_reconstruction_loss: 174.7182
# Epoch 200/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.2510 - loss: 251.5463 - reconstruction_loss: 242.2953 - val_kl_loss: 9.4417 - val_loss: 177.9144 - val_reconstruction_loss: 168.4727
# Epoch 201/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.2673 - loss: 251.1261 - reconstruction_loss: 241.8589 - val_kl_loss: 9.4676 - val_loss: 182.2342 - val_reconstruction_loss: 172.7666
# Epoch 202/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.2752 - loss: 252.4921 - reconstruction_loss: 243.2169 - val_kl_loss: 9.4716 - val_loss: 181.2199 - val_reconstruction_loss: 171.7483
# Epoch 203/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.3011 - loss: 250.6144 - reconstruction_loss: 241.3133 - val_kl_loss: 9.5475 - val_loss: 181.4167 - val_reconstruction_loss: 171.8691
# Epoch 204/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.3228 - loss: 249.7214 - reconstruction_loss: 240.3985 - val_kl_loss: 9.5424 - val_loss: 176.5743 - val_reconstruction_loss: 167.0319
# Epoch 205/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.3327 - loss: 249.2814 - reconstruction_loss: 239.9487 - val_kl_loss: 9.6037 - val_loss: 178.7802 - val_reconstruction_loss: 169.1765
# Epoch 206/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.3290 - loss: 250.6776 - reconstruction_loss: 241.3486 - val_kl_loss: 9.4593 - val_loss: 184.4771 - val_reconstruction_loss: 175.0178
# Epoch 207/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.3535 - loss: 248.8356 - reconstruction_loss: 239.4820 - val_kl_loss: 9.5281 - val_loss: 176.5792 - val_reconstruction_loss: 167.0511
# Epoch 208/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.3654 - loss: 249.2555 - reconstruction_loss: 239.8901 - val_kl_loss: 9.7266 - val_loss: 178.5326 - val_reconstruction_loss: 168.8060
# Epoch 209/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.3670 - loss: 249.8245 - reconstruction_loss: 240.4575 - val_kl_loss: 9.3807 - val_loss: 179.3069 - val_reconstruction_loss: 169.9263
# Epoch 210/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.3402 - loss: 250.0504 - reconstruction_loss: 240.7102 - val_kl_loss: 9.4929 - val_loss: 176.1079 - val_reconstruction_loss: 166.6151
# Epoch 211/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.4006 - loss: 248.2156 - reconstruction_loss: 238.8149 - val_kl_loss: 9.5114 - val_loss: 179.5741 - val_reconstruction_loss: 170.0626
# Epoch 212/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.3592 - loss: 250.2047 - reconstruction_loss: 240.8454 - val_kl_loss: 9.5611 - val_loss: 179.6022 - val_reconstruction_loss: 170.0412
# Epoch 213/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.4054 - loss: 246.2150 - reconstruction_loss: 236.8096 - val_kl_loss: 9.6980 - val_loss: 178.6105 - val_reconstruction_loss: 168.9125
# Epoch 214/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.4241 - loss: 247.9491 - reconstruction_loss: 238.5250 - val_kl_loss: 9.6228 - val_loss: 178.8732 - val_reconstruction_loss: 169.2504
# Epoch 215/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.4291 - loss: 247.8327 - reconstruction_loss: 238.4036 - val_kl_loss: 9.7312 - val_loss: 183.0981 - val_reconstruction_loss: 173.3669
# Epoch 216/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.4751 - loss: 246.6117 - reconstruction_loss: 237.1366 - val_kl_loss: 9.7673 - val_loss: 179.1687 - val_reconstruction_loss: 169.4014
# Epoch 217/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.4604 - loss: 245.8003 - reconstruction_loss: 236.3399 - val_kl_loss: 9.7971 - val_loss: 176.3167 - val_reconstruction_loss: 166.5196
# Epoch 218/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.4685 - loss: 246.5305 - reconstruction_loss: 237.0621 - val_kl_loss: 9.7650 - val_loss: 179.9474 - val_reconstruction_loss: 170.1824
# Epoch 219/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.4879 - loss: 245.7216 - reconstruction_loss: 236.2338 - val_kl_loss: 9.7137 - val_loss: 182.2840 - val_reconstruction_loss: 172.5703
# Epoch 220/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.5067 - loss: 245.7818 - reconstruction_loss: 236.2750 - val_kl_loss: 9.7120 - val_loss: 174.3468 - val_reconstruction_loss: 164.6349
# Epoch 221/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.5281 - loss: 245.0027 - reconstruction_loss: 235.4746 - val_kl_loss: 9.6886 - val_loss: 177.5093 - val_reconstruction_loss: 167.8207
# Epoch 222/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.5567 - loss: 243.7220 - reconstruction_loss: 234.1652 - val_kl_loss: 9.7238 - val_loss: 172.1625 - val_reconstruction_loss: 162.4386
# Epoch 223/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.4735 - loss: 248.7001 - reconstruction_loss: 239.2265 - val_kl_loss: 9.7010 - val_loss: 175.6958 - val_reconstruction_loss: 165.9948
# Epoch 224/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.5272 - loss: 244.5737 - reconstruction_loss: 235.0465 - val_kl_loss: 9.7790 - val_loss: 174.9482 - val_reconstruction_loss: 165.1692
# Epoch 225/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.5028 - loss: 246.3711 - reconstruction_loss: 236.8682 - val_kl_loss: 9.6929 - val_loss: 173.4540 - val_reconstruction_loss: 163.7611
# Epoch 226/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.6029 - loss: 242.1016 - reconstruction_loss: 232.4987 - val_kl_loss: 9.8560 - val_loss: 174.3886 - val_reconstruction_loss: 164.5326
# Epoch 227/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.5804 - loss: 243.1903 - reconstruction_loss: 233.6099 - val_kl_loss: 9.6374 - val_loss: 180.5846 - val_reconstruction_loss: 170.9472
# Epoch 228/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.5955 - loss: 243.5691 - reconstruction_loss: 233.9736 - val_kl_loss: 9.6975 - val_loss: 174.2076 - val_reconstruction_loss: 164.5100
# Epoch 229/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.5764 - loss: 242.6779 - reconstruction_loss: 233.1015 - val_kl_loss: 9.8339 - val_loss: 173.0570 - val_reconstruction_loss: 163.2231
# Epoch 230/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.6143 - loss: 243.0565 - reconstruction_loss: 233.4423 - val_kl_loss: 9.7297 - val_loss: 173.9601 - val_reconstruction_loss: 164.2304
# Epoch 231/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.6404 - loss: 239.8418 - reconstruction_loss: 230.2015 - val_kl_loss: 9.7547 - val_loss: 171.0760 - val_reconstruction_loss: 161.3214
# Epoch 232/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.6497 - loss: 240.9124 - reconstruction_loss: 231.2626 - val_kl_loss: 9.9002 - val_loss: 176.8056 - val_reconstruction_loss: 166.9054
# Epoch 233/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.6544 - loss: 240.9582 - reconstruction_loss: 231.3037 - val_kl_loss: 9.8932 - val_loss: 180.3582 - val_reconstruction_loss: 170.4650
# Epoch 234/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.6744 - loss: 240.0315 - reconstruction_loss: 230.3570 - val_kl_loss: 9.8864 - val_loss: 171.5118 - val_reconstruction_loss: 161.6254
# Epoch 235/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.6758 - loss: 242.1507 - reconstruction_loss: 232.4749 - val_kl_loss: 9.8422 - val_loss: 173.7852 - val_reconstruction_loss: 163.9431
# Epoch 236/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.6739 - loss: 239.6975 - reconstruction_loss: 230.0237 - val_kl_loss: 9.8531 - val_loss: 168.0591 - val_reconstruction_loss: 158.2060
# Epoch 237/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.6567 - loss: 242.7679 - reconstruction_loss: 233.1112 - val_kl_loss: 9.8779 - val_loss: 168.4897 - val_reconstruction_loss: 158.6118
# Epoch 238/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.6778 - loss: 240.5256 - reconstruction_loss: 230.8478 - val_kl_loss: 9.7354 - val_loss: 169.9630 - val_reconstruction_loss: 160.2276
# Epoch 239/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.7137 - loss: 240.6299 - reconstruction_loss: 230.9163 - val_kl_loss: 9.8905 - val_loss: 168.3589 - val_reconstruction_loss: 158.4685
# Epoch 240/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.7189 - loss: 240.0240 - reconstruction_loss: 230.3051 - val_kl_loss: 9.9015 - val_loss: 167.8927 - val_reconstruction_loss: 157.9912
# Epoch 241/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.7606 - loss: 238.2222 - reconstruction_loss: 228.4615 - val_kl_loss: 9.8633 - val_loss: 169.0732 - val_reconstruction_loss: 159.2098
# Epoch 242/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.7758 - loss: 237.3857 - reconstruction_loss: 227.6098 - val_kl_loss: 9.9444 - val_loss: 167.5674 - val_reconstruction_loss: 157.6230
# Epoch 243/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.7312 - loss: 239.1577 - reconstruction_loss: 229.4264 - val_kl_loss: 9.8609 - val_loss: 167.7843 - val_reconstruction_loss: 157.9234
# Epoch 244/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.8110 - loss: 237.4453 - reconstruction_loss: 227.6343 - val_kl_loss: 9.9137 - val_loss: 169.0534 - val_reconstruction_loss: 159.1397
# Epoch 245/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.7800 - loss: 237.3513 - reconstruction_loss: 227.5714 - val_kl_loss: 9.9139 - val_loss: 165.7964 - val_reconstruction_loss: 155.8826
# Epoch 246/400
# 151/151 - 5s - 32ms/step - kl_loss: 9.8245 - loss: 236.8897 - reconstruction_loss: 227.0652 - val_kl_loss: 10.0152 - val_loss: 168.2758 - val_reconstruction_loss: 158.2606
# Epoch 247/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.8027 - loss: 235.4370 - reconstruction_loss: 225.6343 - val_kl_loss: 9.9731 - val_loss: 169.7178 - val_reconstruction_loss: 159.7447
# Epoch 248/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.7937 - loss: 237.9206 - reconstruction_loss: 228.1270 - val_kl_loss: 9.9033 - val_loss: 166.5048 - val_reconstruction_loss: 156.6014
# Epoch 249/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.8371 - loss: 233.4456 - reconstruction_loss: 223.6084 - val_kl_loss: 9.9224 - val_loss: 167.3474 - val_reconstruction_loss: 157.4250
# Epoch 250/400
# 151/151 - 5s - 33ms/step - kl_loss: 9.8068 - loss: 235.2150 - reconstruction_loss: 225.4082 - val_kl_loss: 10.1453 - val_loss: 171.3891 - val_reconstruction_loss: 161.2439
# Epoch 251/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.7932 - loss: 242.0675 - reconstruction_loss: 232.2743 - val_kl_loss: 9.8929 - val_loss: 167.5249 - val_reconstruction_loss: 157.6320
# Epoch 252/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.8248 - loss: 234.9377 - reconstruction_loss: 225.1128 - val_kl_loss: 10.0084 - val_loss: 166.5344 - val_reconstruction_loss: 156.5259
# Epoch 253/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.8387 - loss: 233.2959 - reconstruction_loss: 223.4572 - val_kl_loss: 10.0431 - val_loss: 165.2914 - val_reconstruction_loss: 155.2483
# Epoch 254/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.8339 - loss: 234.3980 - reconstruction_loss: 224.5641 - val_kl_loss: 10.1201 - val_loss: 170.1941 - val_reconstruction_loss: 160.0740
# Epoch 255/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.8751 - loss: 233.5081 - reconstruction_loss: 223.6329 - val_kl_loss: 10.1381 - val_loss: 167.0572 - val_reconstruction_loss: 156.9192
# Epoch 256/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.8496 - loss: 233.7268 - reconstruction_loss: 223.8772 - val_kl_loss: 10.0297 - val_loss: 165.8197 - val_reconstruction_loss: 155.7900
# Epoch 257/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.8739 - loss: 234.1978 - reconstruction_loss: 224.3239 - val_kl_loss: 9.8859 - val_loss: 169.4943 - val_reconstruction_loss: 159.6085
# Epoch 258/400
# 151/151 - 5s - 30ms/step - kl_loss: 9.8705 - loss: 234.4227 - reconstruction_loss: 224.5521 - val_kl_loss: 10.0412 - val_loss: 167.9948 - val_reconstruction_loss: 157.9536
# Epoch 259/400
# 151/151 - 5s - 31ms/step - kl_loss: 9.8828 - loss: 232.6115 - reconstruction_loss: 222.7288 - val_kl_loss: 10.0730 - val_loss: 163.0528 - val_reconstruction_loss: 152.9799
# Epoch 260/400
# ...
# Epoch 316/400
# 151/151 - 5s - 31ms/step - kl_loss: 10.2408 - loss: 225.8018 - reconstruction_loss: 215.5610 - val_kl_loss: 10.4793 - val_loss: 172.8519 - val_reconstruction_loss: 162.3727
# Epoch 317/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.2548 - loss: 227.9573 - reconstruction_loss: 217.7025 - val_kl_loss: 10.3028 - val_loss: 160.8372 - val_reconstruction_loss: 150.5345
# Epoch 318/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.3178 - loss: 218.5859 - reconstruction_loss: 208.2681 - val_kl_loss: 10.3266 - val_loss: 166.9592 - val_reconstruction_loss: 156.6326
# Epoch 319/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.2927 - loss: 219.7367 - reconstruction_loss: 209.4440 - val_kl_loss: 10.4264 - val_loss: 163.3091 - val_reconstruction_loss: 152.8827
# Epoch 320/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.2865 - loss: 220.2739 - reconstruction_loss: 209.9875 - val_kl_loss: 10.4767 - val_loss: 150.9348 - val_reconstruction_loss: 140.4581
# Epoch 321/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.3458 - loss: 222.7928 - reconstruction_loss: 212.4470 - val_kl_loss: 10.4240 - val_loss: 173.4427 - val_reconstruction_loss: 163.0186
# Epoch 322/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.3090 - loss: 221.2540 - reconstruction_loss: 210.9450 - val_kl_loss: 10.3703 - val_loss: 152.1871 - val_reconstruction_loss: 141.8168
# Epoch 323/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.3467 - loss: 215.9209 - reconstruction_loss: 205.5742 - val_kl_loss: 10.4183 - val_loss: 150.8420 - val_reconstruction_loss: 140.4237
# Epoch 324/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.3384 - loss: 222.4221 - reconstruction_loss: 212.0835 - val_kl_loss: 10.2849 - val_loss: 177.6051 - val_reconstruction_loss: 167.3202
# Epoch 325/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.1723 - loss: 231.7907 - reconstruction_loss: 221.6185 - val_kl_loss: 10.4697 - val_loss: 155.3300 - val_reconstruction_loss: 144.8603
# Epoch 326/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.3798 - loss: 219.1527 - reconstruction_loss: 208.7729 - val_kl_loss: 10.5144 - val_loss: 152.6717 - val_reconstruction_loss: 142.1573
# Epoch 327/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.3478 - loss: 222.2019 - reconstruction_loss: 211.8542 - val_kl_loss: 10.4777 - val_loss: 154.6710 - val_reconstruction_loss: 144.1933
# Epoch 328/400
# 151/151 - 5s - 31ms/step - kl_loss: 10.4137 - loss: 217.4352 - reconstruction_loss: 207.0214 - val_kl_loss: 10.4952 - val_loss: 149.8487 - val_reconstruction_loss: 139.3535
# Epoch 329/400
# 151/151 - 5s - 31ms/step - kl_loss: 10.3734 - loss: 221.3504 - reconstruction_loss: 210.9770 - val_kl_loss: 10.5248 - val_loss: 151.5653 - val_reconstruction_loss: 141.0405
# Epoch 330/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.4120 - loss: 217.2904 - reconstruction_loss: 206.8783 - val_kl_loss: 10.5014 - val_loss: 152.1946 - val_reconstruction_loss: 141.6932
# Epoch 331/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.3813 - loss: 215.7226 - reconstruction_loss: 205.3413 - val_kl_loss: 10.4691 - val_loss: 148.7146 - val_reconstruction_loss: 138.2456
# Epoch 332/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.4014 - loss: 214.1060 - reconstruction_loss: 203.7045 - val_kl_loss: 10.6978 - val_loss: 153.5366 - val_reconstruction_loss: 142.8388
# Epoch 333/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.3904 - loss: 221.3135 - reconstruction_loss: 210.9232 - val_kl_loss: 10.3486 - val_loss: 164.6107 - val_reconstruction_loss: 154.2621
# Epoch 334/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.3632 - loss: 221.9721 - reconstruction_loss: 211.6089 - val_kl_loss: 10.6721 - val_loss: 163.5170 - val_reconstruction_loss: 152.8449
# Epoch 335/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.4100 - loss: 217.6172 - reconstruction_loss: 207.2072 - val_kl_loss: 10.5376 - val_loss: 160.6070 - val_reconstruction_loss: 150.0694
# Epoch 336/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.4546 - loss: 217.2157 - reconstruction_loss: 206.7610 - val_kl_loss: 10.4942 - val_loss: 154.2260 - val_reconstruction_loss: 143.7318
# Epoch 337/400
# 151/151 - 4s - 30ms/step - kl_loss: 10.4249 - loss: 216.6910 - reconstruction_loss: 206.2661 - val_kl_loss: 10.5600 - val_loss: 150.2917 - val_reconstruction_loss: 139.7317
# Epoch 338/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.4021 - loss: 220.3876 - reconstruction_loss: 209.9855 - val_kl_loss: 10.4271 - val_loss: 159.9705 - val_reconstruction_loss: 149.5434
# Epoch 339/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.4443 - loss: 216.0757 - reconstruction_loss: 205.6314 - val_kl_loss: 10.5674 - val_loss: 154.0618 - val_reconstruction_loss: 143.4944
# Epoch 340/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.4498 - loss: 217.8421 - reconstruction_loss: 207.3922 - val_kl_loss: 10.6016 - val_loss: 158.1931 - val_reconstruction_loss: 147.5915
# Epoch 341/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.4612 - loss: 218.9424 - reconstruction_loss: 208.4813 - val_kl_loss: 10.4298 - val_loss: 198.3469 - val_reconstruction_loss: 187.9171
# Epoch 342/400
# 151/151 - 5s - 32ms/step - kl_loss: 10.1111 - loss: 232.3274 - reconstruction_loss: 222.2162 - val_kl_loss: 10.6090 - val_loss: 147.0271 - val_reconstruction_loss: 136.4181
# Epoch 343/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.3817 - loss: 220.6975 - reconstruction_loss: 210.3158 - val_kl_loss: 10.5448 - val_loss: 146.8722 - val_reconstruction_loss: 136.3274
# Epoch 344/400
# 151/151 - 5s - 31ms/step - kl_loss: 10.4670 - loss: 212.8535 - reconstruction_loss: 202.3865 - val_kl_loss: 10.5983 - val_loss: 150.8308 - val_reconstruction_loss: 140.2325
# Epoch 345/400
# 151/151 - 4s - 30ms/step - kl_loss: 10.4009 - loss: 218.6853 - reconstruction_loss: 208.2844 - val_kl_loss: 10.5920 - val_loss: 148.0332 - val_reconstruction_loss: 137.4412
# Epoch 346/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.4727 - loss: 211.4604 - reconstruction_loss: 200.9878 - val_kl_loss: 10.5931 - val_loss: 146.4162 - val_reconstruction_loss: 135.8230
# Epoch 347/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.4479 - loss: 213.4886 - reconstruction_loss: 203.0406 - val_kl_loss: 10.7170 - val_loss: 148.3633 - val_reconstruction_loss: 137.6462
# Epoch 348/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.4849 - loss: 211.4386 - reconstruction_loss: 200.9538 - val_kl_loss: 10.6376 - val_loss: 146.1807 - val_reconstruction_loss: 135.5432
# Epoch 349/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.5157 - loss: 211.2323 - reconstruction_loss: 200.7166 - val_kl_loss: 10.6257 - val_loss: 148.1843 - val_reconstruction_loss: 137.5586
# Epoch 350/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.4850 - loss: 216.1413 - reconstruction_loss: 205.6564 - val_kl_loss: 10.6022 - val_loss: 148.7505 - val_reconstruction_loss: 138.1483
# Epoch 351/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.4813 - loss: 215.4442 - reconstruction_loss: 204.9629 - val_kl_loss: 10.6759 - val_loss: 146.8940 - val_reconstruction_loss: 136.2181
# Epoch 352/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.4634 - loss: 215.1333 - reconstruction_loss: 204.6699 - val_kl_loss: 10.4291 - val_loss: 149.8207 - val_reconstruction_loss: 139.3917
# Epoch 353/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.5039 - loss: 215.8296 - reconstruction_loss: 205.3257 - val_kl_loss: 10.5931 - val_loss: 145.1718 - val_reconstruction_loss: 134.5787
# Epoch 354/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.4936 - loss: 214.0831 - reconstruction_loss: 203.5896 - val_kl_loss: 10.6148 - val_loss: 145.1861 - val_reconstruction_loss: 134.5714
# Epoch 355/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.4403 - loss: 223.4440 - reconstruction_loss: 213.0036 - val_kl_loss: 10.9677 - val_loss: 167.5396 - val_reconstruction_loss: 156.5719
# Epoch 356/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.5201 - loss: 218.7249 - reconstruction_loss: 208.2048 - val_kl_loss: 10.6519 - val_loss: 147.1349 - val_reconstruction_loss: 136.4830
# Epoch 357/400
# 151/151 - 5s - 31ms/step - kl_loss: 10.5491 - loss: 214.6625 - reconstruction_loss: 204.1134 - val_kl_loss: 10.5934 - val_loss: 149.8218 - val_reconstruction_loss: 139.2284
# Epoch 358/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.5381 - loss: 212.2665 - reconstruction_loss: 201.7283 - val_kl_loss: 10.5711 - val_loss: 153.7282 - val_reconstruction_loss: 143.1571
# Epoch 359/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.5527 - loss: 217.1664 - reconstruction_loss: 206.6137 - val_kl_loss: 10.4193 - val_loss: 154.6812 - val_reconstruction_loss: 144.2619
# Epoch 360/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.5068 - loss: 208.4814 - reconstruction_loss: 197.9746 - val_kl_loss: 10.7120 - val_loss: 144.7141 - val_reconstruction_loss: 134.0022
# Epoch 361/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.5132 - loss: 217.1740 - reconstruction_loss: 206.6608 - val_kl_loss: 10.6976 - val_loss: 149.5433 - val_reconstruction_loss: 138.8457
# Epoch 362/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.5155 - loss: 219.1891 - reconstruction_loss: 208.6736 - val_kl_loss: 10.6254 - val_loss: 150.7840 - val_reconstruction_loss: 140.1585
# Epoch 363/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.5462 - loss: 211.7944 - reconstruction_loss: 201.2481 - val_kl_loss: 10.6272 - val_loss: 151.8923 - val_reconstruction_loss: 141.2652
# Epoch 364/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.5692 - loss: 213.4337 - reconstruction_loss: 202.8646 - val_kl_loss: 10.6723 - val_loss: 150.8628 - val_reconstruction_loss: 140.1905
# Epoch 365/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.5842 - loss: 207.0351 - reconstruction_loss: 196.4509 - val_kl_loss: 10.7227 - val_loss: 144.5561 - val_reconstruction_loss: 133.8334
# Epoch 366/400
# 151/151 - 4s - 30ms/step - kl_loss: 10.5750 - loss: 208.1002 - reconstruction_loss: 197.5252 - val_kl_loss: 10.7297 - val_loss: 142.7446 - val_reconstruction_loss: 132.0149
# Epoch 367/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.5797 - loss: 209.5525 - reconstruction_loss: 198.9728 - val_kl_loss: 10.6845 - val_loss: 148.2433 - val_reconstruction_loss: 137.5588
# Epoch 368/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.5133 - loss: 212.0147 - reconstruction_loss: 201.5014 - val_kl_loss: 10.6624 - val_loss: 148.6500 - val_reconstruction_loss: 137.9876
# Epoch 369/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.5448 - loss: 219.5245 - reconstruction_loss: 208.9798 - val_kl_loss: 10.4584 - val_loss: 151.1580 - val_reconstruction_loss: 140.6996
# Epoch 370/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.5376 - loss: 212.4217 - reconstruction_loss: 201.8841 - val_kl_loss: 10.6376 - val_loss: 148.3446 - val_reconstruction_loss: 137.7070
# Epoch 371/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.6165 - loss: 210.2500 - reconstruction_loss: 199.6335 - val_kl_loss: 10.7655 - val_loss: 142.7548 - val_reconstruction_loss: 131.9892
# Epoch 372/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.6169 - loss: 208.9988 - reconstruction_loss: 198.3819 - val_kl_loss: 10.6949 - val_loss: 151.3129 - val_reconstruction_loss: 140.6181
# Epoch 373/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.5830 - loss: 214.6017 - reconstruction_loss: 204.0186 - val_kl_loss: 10.6929 - val_loss: 148.1759 - val_reconstruction_loss: 137.4830
# Epoch 374/400
# 151/151 - 5s - 31ms/step - kl_loss: 10.6157 - loss: 207.1672 - reconstruction_loss: 196.5515 - val_kl_loss: 10.7242 - val_loss: 144.4051 - val_reconstruction_loss: 133.6809
# Epoch 375/400
# 151/151 - 5s - 31ms/step - kl_loss: 10.5476 - loss: 216.5622 - reconstruction_loss: 206.0147 - val_kl_loss: 10.7366 - val_loss: 142.6875 - val_reconstruction_loss: 131.9509
# Epoch 376/400
# 151/151 - 4s - 30ms/step - kl_loss: 10.5630 - loss: 205.2016 - reconstruction_loss: 194.6385 - val_kl_loss: 10.7000 - val_loss: 142.7508 - val_reconstruction_loss: 132.0509
# Epoch 377/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.5699 - loss: 211.5294 - reconstruction_loss: 200.9596 - val_kl_loss: 10.5255 - val_loss: 145.8767 - val_reconstruction_loss: 135.3512
# Epoch 378/400
# 151/151 - 5s - 31ms/step - kl_loss: 10.5221 - loss: 209.3183 - reconstruction_loss: 198.7962 - val_kl_loss: 10.6640 - val_loss: 141.2085 - val_reconstruction_loss: 130.5445
# Epoch 379/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.6309 - loss: 208.8713 - reconstruction_loss: 198.2403 - val_kl_loss: 10.8304 - val_loss: 152.9747 - val_reconstruction_loss: 142.1443
# Epoch 380/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.5836 - loss: 213.1958 - reconstruction_loss: 202.6122 - val_kl_loss: 10.6939 - val_loss: 157.0334 - val_reconstruction_loss: 146.3394
# Epoch 381/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.6338 - loss: 206.3925 - reconstruction_loss: 195.7588 - val_kl_loss: 10.7626 - val_loss: 141.5359 - val_reconstruction_loss: 130.7733
# Epoch 382/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.6213 - loss: 209.2899 - reconstruction_loss: 198.6686 - val_kl_loss: 10.7230 - val_loss: 144.8581 - val_reconstruction_loss: 134.1351
# Epoch 383/400
# 151/151 - 5s - 31ms/step - kl_loss: 10.6540 - loss: 207.1133 - reconstruction_loss: 196.4592 - val_kl_loss: 10.7343 - val_loss: 145.1633 - val_reconstruction_loss: 134.4291
# Epoch 384/400
# 151/151 - 4s - 30ms/step - kl_loss: 10.6530 - loss: 207.0106 - reconstruction_loss: 196.3575 - val_kl_loss: 10.8109 - val_loss: 142.0184 - val_reconstruction_loss: 131.2075
# Epoch 385/400
# 151/151 - 5s - 31ms/step - kl_loss: 10.6271 - loss: 209.4132 - reconstruction_loss: 198.7862 - val_kl_loss: 10.8081 - val_loss: 153.1571 - val_reconstruction_loss: 142.3490
# Epoch 386/400
# 151/151 - 5s - 31ms/step - kl_loss: 10.5550 - loss: 219.8717 - reconstruction_loss: 209.3166 - val_kl_loss: 10.6859 - val_loss: 156.3490 - val_reconstruction_loss: 145.6631
# Epoch 387/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.6349 - loss: 207.1928 - reconstruction_loss: 196.5579 - val_kl_loss: 10.7335 - val_loss: 142.6631 - val_reconstruction_loss: 131.9296
# Epoch 388/400
# 151/151 - 5s - 33ms/step - kl_loss: 10.6439 - loss: 215.0671 - reconstruction_loss: 204.4232 - val_kl_loss: 10.8901 - val_loss: 147.9907 - val_reconstruction_loss: 137.1006
# Epoch 389/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.6506 - loss: 207.9120 - reconstruction_loss: 197.2615 - val_kl_loss: 10.7342 - val_loss: 142.4323 - val_reconstruction_loss: 131.6981
# Epoch 390/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.7085 - loss: 205.6486 - reconstruction_loss: 194.9401 - val_kl_loss: 10.8746 - val_loss: 142.4351 - val_reconstruction_loss: 131.5605
# Epoch 391/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.7030 - loss: 207.7117 - reconstruction_loss: 197.0087 - val_kl_loss: 10.9318 - val_loss: 172.2321 - val_reconstruction_loss: 161.3003
# Epoch 392/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.6688 - loss: 206.7677 - reconstruction_loss: 196.0988 - val_kl_loss: 10.7950 - val_loss: 143.7100 - val_reconstruction_loss: 132.9150
# Epoch 393/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.6563 - loss: 207.0011 - reconstruction_loss: 196.3448 - val_kl_loss: 10.7805 - val_loss: 146.4842 - val_reconstruction_loss: 135.7037
# Epoch 394/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.6970 - loss: 208.7285 - reconstruction_loss: 198.0315 - val_kl_loss: 10.7927 - val_loss: 144.7579 - val_reconstruction_loss: 133.9652
# Epoch 395/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.6711 - loss: 202.9542 - reconstruction_loss: 192.2831 - val_kl_loss: 10.7920 - val_loss: 140.7939 - val_reconstruction_loss: 130.0019
# Epoch 396/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.6728 - loss: 204.8974 - reconstruction_loss: 194.2246 - val_kl_loss: 10.8031 - val_loss: 142.7904 - val_reconstruction_loss: 131.9873
# Epoch 397/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.6661 - loss: 206.6085 - reconstruction_loss: 195.9425 - val_kl_loss: 10.8089 - val_loss: 144.8846 - val_reconstruction_loss: 134.0757
# Epoch 398/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.6531 - loss: 213.0024 - reconstruction_loss: 202.3493 - val_kl_loss: 10.8539 - val_loss: 146.4596 - val_reconstruction_loss: 135.6057
# Epoch 399/400
# 151/151 - 5s - 30ms/step - kl_loss: 10.6907 - loss: 206.1810 - reconstruction_loss: 195.4902 - val_kl_loss: 10.7778 - val_loss: 141.6608 - val_reconstruction_loss: 130.8830
# Epoch 400/400
# 151/151 - 5s - 31ms/step - kl_loss: 10.7034 - loss: 202.9952 - reconstruction_loss: 192.2918 - val_kl_loss: 10.7719 - val_loss: 140.2532 - val_reconstruction_loss: 129.4813
# CPU times: user 25min 59s, sys: 3min 25s, total: 29min 25s
# Wall time: 31min 39s

# %% [markdown]
# ## Test Encoder
# Here we will generate new data signals that the model has not encountered before to see how it will handle them

# %%
import pandas as pd
import hvplot.pandas

# %%
df = pd.DataFrame(encoder.predict(X_val, batch_size=4096), 
                          columns=['x', 'y']
                         )
df['labels'] = labels_val
df.head()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step
#           x         y  labels
# 0  1.015762 -0.272340      13
# 1 -0.395363  2.069585      28
# 2 -0.301319 -0.491568      10
# 3 -0.030817 -0.184556      28
# 4 -0.264534  0.515414      -1

# %%
fig = (
    df.query("labels.ge(0)").hvplot.scatter(
        x="x",
        y="y",
        hover=False,
        s=1,
        by="labels",
        color=hv.Cycle(colors[1:]),
        title="encoded data",
        width=800,
        height=600,
        legend=False,
    )
).relabel(
    "data"
) * (
    df.query("labels.lt(0)")
    .hvplot.scatter(
        x="x",
        y="y",
        hover=False,
        s=1,
        color="red",
    )
    .relabel("noise")
)

# %%
new = np.stack(
    [
        generate_signal(SEQUENCE_LENGTH, 1, 
                        freq_range=(2, 15),
                       )[1]
        for i in range(N_FEATURES)
    ],
    axis=1,
).reshape(-1, SEQUENCE_LENGTH, N_FEATURES)
new = (new - new.min()) / (new.max() - new.min())

# Create time encoder
t_enc = np.zeros(SEQUENCE_LENGTH).astype(new.dtype)
for i in TIME_ENC_L:
    t_enc += (0.5 * (np.cos(2 * i * np.pi * np.arange(SEQUENCE_LENGTH) / SEQUENCE_LENGTH) + 1)).astype(new.dtype)
t_enc = t_enc.reshape(1, SEQUENCE_LENGTH, 1)

# add time encoder
new = np.concatenate((new, t_enc), axis=-1)  # try np.roll with t_enc to see the time encoding on the circular plot

new_enc = encoder.predict_on_batch(new)  # 1 pattern

fig * hv.Scatter(new_enc).opts(size=20, marker="o", color="white").relabel("new data")
# Out:
# :Overlay
#    .NdOverlay.Data   :NdOverlay   [labels]
#       :Scatter   [x]   (y)
#    .Scatter.Noise    :Scatter   [x]   (y)
#    .Scatter.New_data :Scatter   [x]   (y)

# %%
new_outlier = np.stack(
                [generate_signal(SEQUENCE_LENGTH, 
                                 1, 
                                 freq_range=(40, 60),
                                 )[1] for i in range(N_FEATURES)],
                                 
                axis=1,
            ).reshape(-1, SEQUENCE_LENGTH, N_FEATURES)

new_outlier = limit(new_outlier)

new_outlier = np.concatenate((new_outlier, t_enc), axis=-1)

new_out_enc = encoder.predict_on_batch(new_outlier)  # 1 pattern
fig * hv.Scatter(new_enc).opts(
    size=20, marker="o", color="white"
).relabel("new data") * hv.Scatter(new_out_enc).opts(
    size=20, marker="o", color="hotpink"
).relabel("new outlier")
# Out:
# :Overlay
#    .NdOverlay.Data      :NdOverlay   [labels]
#       :Scatter   [x]   (y)
#    .Scatter.Noise       :Scatter   [x]   (y)
#    .Scatter.New_data    :Scatter   [x]   (y)
#    .Scatter.New_outlier :Scatter   [x]   (y)

# %%
# Roll time encoder 1/4 Sequence length
rotation = 0.4
new_other = np.concatenate((new[..., :-1], np.roll(t_enc, int(SEQUENCE_LENGTH * rotation))), axis=-1)

new_other_enc = encoder.predict_on_batch(new_other)

fig * hv.Scatter(new_enc).opts(size=20, marker="o", color="white").relabel(
    "new data"
) * hv.Scatter(new_out_enc).opts(size=20, marker="o", color="hotpink").relabel(
    "new high F outlier"
) * hv.Scatter(
    new_other_enc
).opts(
    size=20, marker="diamond", color="blue"
).relabel(
    f"new data {rotation * 100}% shifted"
)
# Out:
# :Overlay
#    .NdOverlay.Data                                  :NdOverlay   [labels]
#       :Scatter   [x]   (y)
#    .Scatter.Noise                                   :Scatter   [x]   (y)
#    .Scatter.New_data                                :Scatter   [x]   (y)
#    .Scatter.New_high_F_outlier                      :Scatter   [x]   (y)
#    .Scatter.New_data_40_full_stop_0_percent_shifted :Scatter   [x]   (y)
